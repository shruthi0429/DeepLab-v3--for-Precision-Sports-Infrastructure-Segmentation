# %%
# Install required packages
# !pip install diffusers==0.24.0 transformers==4.36.2 torch accelerate xformers

import torch
from diffusers import StableDiffusionPipeline
from PIL import Image
import os
from tqdm.auto import tqdm
import random

def setup_stable_diffusion():
    """Initialize the Stable Diffusion pipeline with optimal settings."""
    model_id = "stabilityai/stable-diffusion-2-1"

    # Initialize pipeline with GPU acceleration
    pipe = StableDiffusionPipeline.from_pretrained(
        model_id,
        torch_dtype=torch.float16,
        safety_checker=None  # Disable safety checker for speed
    )
    pipe = pipe.to("cuda")
    pipe.enable_xformers_memory_efficient_attention()

    return pipe

def get_campus_prompts():
    """Generate a list of diverse campus prompts with tennis courts and swimming pools."""
    tennis_court_prompts = [
        "Tennis court on a university campus, surrounded by greenery, daytime",
        "Modern campus tennis court with students playing, clear sky",
        "Tennis court with chain-link fence, campus buildings in background",
        "University campus tennis court, late afternoon sunlight",
        "Rainy day on campus tennis court, wet ground reflections"
    ]

    swimming_pool_prompts = [
        "Outdoor swimming pool on a university campus, surrounded by palm trees",
        "Campus swimming pool with students relaxing, sunny day",
        "Modern campus pool at sunset, warm lighting, reflections",
        "University campus pool with lounge chairs, overcast day",
        "Swimming pool on campus, early morning with misty water"
    ]

    combined_prompts = [
        "University campus with both a tennis court and a swimming pool, sunny day",
        "Aerial view of campus showing tennis court and swimming pool, surrounded by trees",
        "Campus scene with swimming pool and tennis court side by side, students relaxing",
        "Tennis court and swimming pool on a university campus, late afternoon sunlight",
        "Campus tennis court next to a pool, with students playing and relaxing, clear sky"
    ]

    angle_prompts = [
        "Aerial view of campus tennis court and swimming pool, surrounded by trees",
        "Low angle shot of campus tennis court with swimming pool in the background",
        "Eye-level view showing campus swimming pool and tennis court with nearby buildings",
        "Ground-level shot of university swimming pool next to tennis court, modern design"
    ]

    all_prompts = tennis_court_prompts + swimming_pool_prompts + combined_prompts + angle_prompts

    # Add quality modifiers to each prompt
    quality_suffix = ", professional photography, 4k, high resolution, photorealistic, architectural photography"
    return [p + quality_suffix for p in all_prompts]

def get_negative_prompt():
    """Return negative prompt to avoid common issues."""
    return ("blurry, distorted, unrealistic, poor quality, low resolution, "
            "oversaturated, cartoon, anime, drawing, painting, artwork, "
            "graffiti, text, watermark, signature, deformed, mutated")

def generate_images(pipe, output_dir, num_images=200, batch_size=4):
    """Generate campus tennis court and swimming pool images using Stable Diffusion."""
    os.makedirs(output_dir, exist_ok=True)

    prompts = get_campus_prompts()
    negative_prompt = get_negative_prompt()

    # Parameters for generation
    generator = torch.Generator(device="cuda")

    with torch.inference_mode():
        for i in tqdm(range(0, num_images, batch_size)):
            # Randomly select prompts for this batch
            batch_prompts = [random.choice(prompts) for _ in range(batch_size)]

            # Generate images
            generator.manual_seed(i)  # For reproducibility
            results = pipe(
                prompt=batch_prompts,
                negative_prompt=[negative_prompt] * batch_size,
                num_inference_steps=50,
                guidance_scale=7.5,
                width=512,
                height=512,
                generator=generator
            )

            # Save images
            for j, image in enumerate(results.images):
                idx = i + j
                if idx >= num_images:
                    break

                image_path = os.path.join(output_dir, f"campus_scenery_{idx:04d}.png")
                image.save(image_path)

def main():
    """Main function to generate campus tennis court and swimming pool dataset."""
    output_dir = "campus_scenery_dataset"
    num_images = 200  # Total images to generate

    print("Setting up Stable Diffusion pipeline...")
    pipe = setup_stable_diffusion()

    print(f"Generating {num_images} images...")
    generate_images(pipe, output_dir, num_images)

    print(f"Dataset generation complete. Images saved in {output_dir}/")

# Run the generation process
if __name__ == "__main__":
    main()
# Out:
# Requirement already satisfied: diffusers==0.24.0 in /usr/local/lib/python3.10/dist-packages (0.24.0)
# Requirement already satisfied: transformers==4.36.2 in /usr/local/lib/python3.10/dist-packages (4.36.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.34.2)
# Requirement already satisfied: xformers in /usr/local/lib/python3.10/dist-packages (0.0.28.post3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers==0.24.0) (10.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers==0.24.0) (3.16.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.24.0) (0.24.7)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers==0.24.0) (8.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffusers==0.24.0) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.24.0) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers==0.24.0) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.24.0) (0.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (6.0.2)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (0.15.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (4.66.6)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.10/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.10/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.10/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.10/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.10/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.10/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers==0.24.0) (3.20.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.24.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.24.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.24.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.24.0) (2024.8.30)
# /usr/local/lib/python3.10/dist-packages/diffusers/utils/outputs.py:63: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/diffusers/utils/outputs.py:63: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# Setting up Stable Diffusion pipeline...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# Generating 200 images...
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Dataset generation complete. Images saved in campus_scenery_dataset/

# %%
# Zip the entire dataset folder
# !zip -r campus_scenery_dataset.zip campus_scenery_dataset/
# Out:
# updating: campus_scenery_dataset/ (stored 0%)
# updating: campus_scenery_dataset/campus_scenery_0086.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0146.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0072.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0179.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0176.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0062.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0180.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0037.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0154.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0055.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0188.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0116.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0092.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0113.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0190.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0056.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0083.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0187.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0087.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0026.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0067.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0070.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0102.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0054.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0032.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0185.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0148.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0114.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0169.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0141.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0109.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0132.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0061.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0085.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0033.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0174.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0172.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0112.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0082.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0034.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0073.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0041.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0195.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0170.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0098.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0103.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0081.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0163.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0158.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0184.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0175.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0074.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0157.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0015.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0108.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0111.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0047.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0005.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0123.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0161.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0198.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0084.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0080.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0173.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0167.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0023.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0028.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0117.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0105.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0025.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0100.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0156.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0065.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0155.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0010.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0078.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0145.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0193.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0127.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0077.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0024.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0089.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0129.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0043.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0071.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0050.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0064.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0095.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0068.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0030.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0120.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0079.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0012.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0045.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0038.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0020.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0107.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0002.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0007.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0000.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0088.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0052.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0166.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0182.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0075.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0138.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0152.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0134.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0099.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0044.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0189.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0093.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0042.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0027.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0014.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0059.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0126.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0125.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0130.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0046.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0096.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0186.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0018.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0016.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0142.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0137.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0091.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0051.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0140.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0124.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0017.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0090.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0057.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0135.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0192.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0060.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0119.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0008.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0009.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0029.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0031.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0128.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0013.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0191.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0143.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0144.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0183.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0159.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0118.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0168.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0019.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0153.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0160.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0022.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0097.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0058.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0106.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0036.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0001.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0069.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0039.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0149.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0122.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0006.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0139.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0004.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0164.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0181.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0094.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0053.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0165.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0063.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0136.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0131.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0197.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0104.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0171.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0133.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0178.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0121.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0196.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0199.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0194.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0151.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0066.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0040.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0076.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0115.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0150.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0048.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0003.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0011.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0049.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0147.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0162.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0177.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0110.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0101.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0035.png (deflated 0%)
# updating: campus_scenery_dataset/campus_scenery_0021.png (deflated 0%)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pillow numpy
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (10.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)

# %%
import os
import json
import numpy as np
from PIL import Image, ImageDraw

# Define color values for each label
label_colors = {
    "background": 0,
    "swimming_pool": 1,
    "tennis_court": 2
}

def json_to_png(json_path, output_path):
    """Convert a single JSON file to a single-channel PNG mask image."""
    with open(json_path, 'r') as f:
        data = json.load(f)

    height = data['imageHeight']
    width = data['imageWidth']

    # Initialize mask with background color
    mask = np.zeros((height, width), dtype=np.uint8)

    # Draw each shape in the JSON as a polygon
    for shape in data['shapes']:
        label = shape['label']
        points = shape['points']
        color = label_colors.get(label, 0)  # Default to background if label not found

        # Convert points to a format suitable for PIL.ImageDraw
        polygon = np.array(points, np.int32).reshape((-1, 2))

        # Draw filled polygon on mask
        img = Image.fromarray(mask)
        ImageDraw.Draw(img).polygon(polygon.tolist(), outline=color, fill=color)
        mask = np.array(img)

    # Save the mask as PNG
    Image.fromarray(mask).save(output_path)

# Define input and output directories
input_dir = "/content/drive/MyDrive/json-images"  # Update with your JSON files folder path
output_dir = "/content/drive/MyDrive/MyProject/mask_outputs"  # Update with your output folder path
os.makedirs(output_dir, exist_ok=True)

# Convert all JSON files in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith(".json"):
        json_path = os.path.join(input_dir, filename)
        png_path = os.path.join(output_dir, filename.replace(".json", ".png"))
        json_to_png(json_path, png_path)

print("Conversion complete! All masks saved to", output_dir)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-2cdfb3ea72a6> in <cell line: 47>()
#      49         json_path = os.path.join(input_dir, filename)
#      50         png_path = os.path.join(output_dir, filename.replace(".json", ".png"))
# ---> 51         json_to_png(json_path, png_path)
#      52
#      53 print("Conversion complete! All masks saved to", output_dir)
#
# <ipython-input-3-2cdfb3ea72a6> in json_to_png(json_path, output_path)
#      33         # Draw filled polygon on mask
#      34         img = Image.fromarray(mask)
# ---> 35         ImageDraw.Draw(img).polygon(polygon.tolist(), outline=color, fill=color)
#      36         mask = np.array(img)
#      37
#
# /usr/local/lib/python3.10/dist-packages/PIL/ImageDraw.py in polygon(self, xy, fill, outline, width)
#     360         ink, fill_ink = self._getink(outline, fill)
#     361         if fill_ink is not None:
# --> 362             self.draw.draw_polygon(xy, fill_ink, 1)
#     363         if ink is not None and ink != fill_ink and width != 0:
#     364             if width == 1:
#
# ValueError: incorrect coordinate type

# %%
import os
import json
import numpy as np
from PIL import Image, ImageDraw

# Define color values for each label
label_colors = {
    "background": 0,
    "swimming_pool": 1,
    "tennis_court": 2
}

def json_to_png(json_path, output_path):
    """Convert a single JSON file to a single-channel PNG mask image."""
    with open(json_path, 'r') as f:
        data = json.load(f)

    height = data['imageHeight']
    width = data['imageWidth']

    # Initialize mask with background color
    mask = np.zeros((height, width), dtype=np.uint8)

    # Draw each shape in the JSON as a polygon
    for shape in data['shapes']:
        label = shape['label']
        points = shape['points']
        color = label_colors.get(label, 0)  # Default to background if label not found

        # Convert points to a format suitable for PIL.ImageDraw
        polygon = np.array(points, np.int32).reshape((-1, 2))

        # Draw filled polygon on mask
        img = Image.fromarray(mask)
        ImageDraw.Draw(img).polygon(polygon.tolist(), outline=color, fill=color)
        mask = np.array(img)

    # Save the mask as PNG
    Image.fromarray(mask).save(output_path)

# Define input and output directories
input_dir = "/content/drive/MyDrive/json-images"  # Update with your JSON files folder path
output_dir = "/content/drive/MyDrive/MyProject/mask_outputs"  # Update with your output folder path
os.makedirs(output_dir, exist_ok=True)

# Convert all JSON files in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith(".json"):
        json_path = os.path.join(input_dir, filename)
        png_path = os.path.join(output_dir, filename.replace(".json", ".png"))
        json_to_png(json_path, png_path)

print("Conversion complete! All masks saved to", output_dir)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-2cdfb3ea72a6> in <cell line: 47>()
#      49         json_path = os.path.join(input_dir, filename)
#      50         png_path = os.path.join(output_dir, filename.replace(".json", ".png"))
# ---> 51         json_to_png(json_path, png_path)
#      52
#      53 print("Conversion complete! All masks saved to", output_dir)
#
# <ipython-input-4-2cdfb3ea72a6> in json_to_png(json_path, output_path)
#      33         # Draw filled polygon on mask
#      34         img = Image.fromarray(mask)
# ---> 35         ImageDraw.Draw(img).polygon(polygon.tolist(), outline=color, fill=color)
#      36         mask = np.array(img)
#      37
#
# /usr/local/lib/python3.10/dist-packages/PIL/ImageDraw.py in polygon(self, xy, fill, outline, width)
#     360         ink, fill_ink = self._getink(outline, fill)
#     361         if fill_ink is not None:
# --> 362             self.draw.draw_polygon(xy, fill_ink, 1)
#     363         if ink is not None and ink != fill_ink and width != 0:
#     364             if width == 1:
#
# ValueError: incorrect coordinate type

# %%
# Define input and output directories
input_dir = "/content/drive/MyDrive/json-images"  # Replace with your actual path to JSON files
output_dir = "/content/drive/MyDrive/MyProject/mask_outputs"  # Replace with your desired output folder path
os.makedirs(output_dir, exist_ok=True)

# Conversion script
import os
import json
import numpy as np
from PIL import Image, ImageDraw

# Define color values for each label
label_colors = {
    "background": 0,
    "swimming_pool": 1,
    "tennis_court": 2
}

def json_to_png(json_path, output_path):
    """Convert a single JSON file to a single-channel PNG mask image."""
    with open(json_path, 'r') as f:
        data = json.load(f)

    height = data['imageHeight']
    width = data['imageWidth']

    # Initialize mask with background color
    mask = np.zeros((height, width), dtype=np.uint8)

    # Draw each shape in the JSON as a polygon
    for shape in data['shapes']:
        label = shape['label']
        points = shape['points']
        color = label_colors.get(label, 0)  # Default to background if label not found

        # Convert points to list of tuples
        polygon = [(int(point[0]), int(point[1])) for point in points]

        # Draw filled polygon on mask
        img = Image.fromarray(mask)
        ImageDraw.Draw(img).polygon(polygon, outline=color, fill=color)
        mask = np.array(img)

    # Save the mask as PNG
    Image.fromarray(mask).save(output_path)

# Convert all JSON files in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith(".json"):
        json_path = os.path.join(input_dir, filename)
        png_path = os.path.join(output_dir, filename.replace(".json", ".png"))
        json_to_png(json_path, png_path)

print("Conversion complete! All masks saved to", output_dir)
# Out:
# Conversion complete! All masks saved to /content/drive/MyDrive/MyProject/mask_outputs

# %%
# Import necessary libraries
import os
import json
import numpy as np
from PIL import Image, ImageDraw

# Define color values for each label
label_colors = {
    "background": 0,       # Black
    "swimming_pool": 1,    # Blue (1 in single-channel)
    "tennis_court": 2      # Green (2 in single-channel)
}

def json_to_png(json_path, output_path):
    """Convert a single JSON file to a single-channel PNG mask image."""
    with open(json_path, 'r') as f:
        data = json.load(f)

    height = data['imageHeight']
    width = data['imageWidth']

    # Initialize mask with background color
    mask = np.zeros((height, width), dtype=np.uint8)

    # Draw each shape in the JSON as a polygon
    for shape in data['shapes']:
        label = shape['label']
        points = shape['points']
        color = label_colors.get(label, 0)  # Default to background if label not found

        if color == 0:
            # Skip unrecognized labels (if needed)
            print(f"Skipping unrecognized label: {label}")
            continue

        # Convert points to a format suitable for PIL.ImageDraw (list of tuples)
        polygon = [(int(point[0]), int(point[1])) for point in points]

        # Draw filled polygon on mask
        img = Image.fromarray(mask)
        draw = ImageDraw.Draw(img)
        draw.polygon(polygon, outline=color, fill=color)

        # Update mask array with drawn polygon
        mask = np.array(img)

    # Save the mask as PNG with single-channel
    Image.fromarray(mask).save(output_path)

# Define input and output directories
input_dir = "/content/drive/MyDrive/json-images"  # Update with your JSON files folder path
output_dir = "/content/drive/MyDrive/MyProject/mask_outputs2"  # Update with your output folder path
os.makedirs(output_dir, exist_ok=True)

# Convert all JSON files in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith(".json"):
        json_path = os.path.join(input_dir, filename)
        png_path = os.path.join(output_dir, filename.replace(".json", ".png"))
        json_to_png(json_path, png_path)

print("Conversion complete! All masks saved to", output_dir)
# Out:
# Skipping unrecognized label: campus_21
# Skipping unrecognized label: campus_20
# Skipping unrecognized label: campus_10
# Skipping unrecognized label: campus_19
# Skipping unrecognized label: campus_18
# Skipping unrecognized label: campus_17
# Skipping unrecognized label: campus_16
# Skipping unrecognized label: campus_05
# Skipping unrecognized label: campus_04
# Skipping unrecognized label: campus_03
# Skipping unrecognized label: campus_00
# Skipping unrecognized label: campus_15
# Skipping unrecognized label: campus_14
# Skipping unrecognized label: campus_01
# Skipping unrecognized label: campus_13
# Skipping unrecognized label: campus_12
# Skipping unrecognized label: campus_11
# Skipping unrecognized label: campus_06
# Skipping unrecognized label: campus_07
# Skipping unrecognized label: campus_08
# Skipping unrecognized label: campus_09
# Skipping unrecognized label: campus_02
# Skipping unrecognized label: campus_39
# Skipping unrecognized label: campus_38
# Skipping unrecognized label: campus_37
# Skipping unrecognized label: campus_36
# Skipping unrecognized label: campus_35
# Skipping unrecognized label: campus_33
# Skipping unrecognized label: campus_34
# Skipping unrecognized label: campus_32
# Skipping unrecognized label: campus_23
# Skipping unrecognized label: campus_27
# Skipping unrecognized label: campus_31
# Skipping unrecognized label: campus_30
# Skipping unrecognized label: campus_22
# Skipping unrecognized label: campus_25
# Skipping unrecognized label: campus_24
# Skipping unrecognized label: campus_26
# Skipping unrecognized label: campus_28
# Skipping unrecognized label: campus_29
# Skipping unrecognized label: campus_59
# Skipping unrecognized label: campus_58
# Skipping unrecognized label: campus_57
# Skipping unrecognized label: campus_56
# Skipping unrecognized label: campus_55
# Skipping unrecognized label: campus_52
# Skipping unrecognized label: campus_54
# Skipping unrecognized label: campus_53
# Skipping unrecognized label: campus_50
# Skipping unrecognized label: campus_51
# Skipping unrecognized label: campus_48
# Skipping unrecognized label: campus_49
# Skipping unrecognized label: campus_47
# Skipping unrecognized label: campus_40
# Skipping unrecognized label: campus_42
# Skipping unrecognized label: campus_45
# Skipping unrecognized label: campus_41
# Skipping unrecognized label: campus_43
# Skipping unrecognized label: campus_44
# Skipping unrecognized label: campus_46
# Skipping unrecognized label: campus_78
# Skipping unrecognized label: campus_77
# Skipping unrecognized label: campus_76
# Skipping unrecognized label: campus_75
# Skipping unrecognized label: campus_74
# Skipping unrecognized label: campus_73
# Skipping unrecognized label: campus_71
# Skipping unrecognized label: campus_72
# Skipping unrecognized label: campus_70
# Skipping unrecognized label: campus_68
# Skipping unrecognized label: campus_69
# Skipping unrecognized label: campus_67
# Skipping unrecognized label: campus_66
# Skipping unrecognized label: campus_65
# Skipping unrecognized label: campus_64
# Skipping unrecognized label: campus_60
# Skipping unrecognized label: campus_63
# Skipping unrecognized label: campus_62
# Skipping unrecognized label: campus_61
# Skipping unrecognized label: campus_95
# Skipping unrecognized label: campus_94
# Skipping unrecognized label: campus_93
# Skipping unrecognized label: campus_91
# Skipping unrecognized label: campus_92
# Skipping unrecognized label: campus_90
# Skipping unrecognized label: campus_89
# Skipping unrecognized label: campus_88
# Skipping unrecognized label: campus_87
# Skipping unrecognized label: campus_86
# Skipping unrecognized label: campus_85
# Skipping unrecognized label: campus_84
# Skipping unrecognized label: campus_82
# Skipping unrecognized label: campus_83
# Skipping unrecognized label: campus_81
# Skipping unrecognized label: campus_80
# Skipping unrecognized label: campus_79
# Skipping unrecognized label: campus_119
# Skipping unrecognized label: campus_118
# Skipping unrecognized label: campus_117
# Skipping unrecognized label: campus_116
# Skipping unrecognized label: campus_115
# Skipping unrecognized label: campus_114
# Skipping unrecognized label: campus_113
# Skipping unrecognized label: campus_112
# Skipping unrecognized label: campus_111
# Skipping unrecognized label: campus_110
# Skipping unrecognized label: campus_109
# Skipping unrecognized label: campus_108
# Skipping unrecognized label: campus_107
# Skipping unrecognized label: campus_106
# Skipping unrecognized label: campus_105
# Skipping unrecognized label: campus_104
# Skipping unrecognized label: campus_103
# Skipping unrecognized label: campus_102
# Skipping unrecognized label: campus_101
# Skipping unrecognized label: campus_100
# Skipping unrecognized label: campus_99
# Skipping unrecognized label: campus_98
# Skipping unrecognized label: campus_96
# Skipping unrecognized label: campus_97
# Skipping unrecognized label: campus_127
# Skipping unrecognized label: campus_140
# Skipping unrecognized label: campus_139
# Skipping unrecognized label: campus_138
# Skipping unrecognized label: campus_137
# Skipping unrecognized label: campus_136
# Skipping unrecognized label: campus_135
# Skipping unrecognized label: campus_134
# Skipping unrecognized label: campus_133
# Skipping unrecognized label: campus_132
# Skipping unrecognized label: campus_130
# Skipping unrecognized label: campus_131
# Skipping unrecognized label: campus_129
# Skipping unrecognized label: campus_128
# Skipping unrecognized label: campus_125
# Skipping unrecognized label: campus_126
# Skipping unrecognized label: campus_123
# Skipping unrecognized label: campus_124
# Skipping unrecognized label: campus_121
# Skipping unrecognized label: campus_122
# Skipping unrecognized label: campus_120
# Skipping unrecognized label: campus_194
# Skipping unrecognized label: campus_193
# Skipping unrecognized label: campus_192
# Skipping unrecognized label: campus_191
# Skipping unrecognized label: campus_190
# Skipping unrecognized label: campus_189
# Skipping unrecognized label: campus_188
# Skipping unrecognized label: campus_187
# Skipping unrecognized label: campus_186
# Skipping unrecognized label: campus_172
# Skipping unrecognized label: campus_171
# Skipping unrecognized label: campus_170
# Skipping unrecognized label: campus_183
# Skipping unrecognized label: campus_177
# Skipping unrecognized label: campus_180
# Skipping unrecognized label: campus_175
# Skipping unrecognized label: campus_182
# Skipping unrecognized label: campus_173
# Skipping unrecognized label: campus_181
# Skipping unrecognized label: campus_169
# Skipping unrecognized label: campus_179
# Skipping unrecognized label: campus_178
# Skipping unrecognized label: campus_168
# Skipping unrecognized label: campus_174
# Skipping unrecognized label: campus_176
# Skipping unrecognized label: campus_185
# Skipping unrecognized label: campus_184
# Skipping unrecognized label: campus_161
# Skipping unrecognized label: campus_167
# Skipping unrecognized label: campus_150
# Skipping unrecognized label: campus_154
# Skipping unrecognized label: campus_160
# Skipping unrecognized label: campus_164
# Skipping unrecognized label: campus_166
# Skipping unrecognized label: campus_153
# Skipping unrecognized label: campus_142
# Skipping unrecognized label: campus_143
# Skipping unrecognized label: campus_163
# Skipping unrecognized label: campus_141
# Skipping unrecognized label: campus_149
# Skipping unrecognized label: campus_148
# Skipping unrecognized label: campus_165
# Skipping unrecognized label: campus_151
# Skipping unrecognized label: campus_162
# Skipping unrecognized label: campus_144
# Skipping unrecognized label: campus_147
# Skipping unrecognized label: campus_145
# Skipping unrecognized label: campus_146
# Skipping unrecognized label: campus_155
# Skipping unrecognized label: campus_156
# Skipping unrecognized label: campus_159
# Skipping unrecognized label: campus_157
# Skipping unrecognized label: campus_158
# Skipping unrecognized label: campus_152
# Skipping unrecognized label: campus_195
# Skipping unrecognized label: campus_196
# Skipping unrecognized label: campus_199
# Skipping unrecognized label: campus_197
# Skipping unrecognized label: campus_198
# Conversion complete! All masks saved to /content/drive/MyDrive/MyProject/mask_outputs2

# %%
import os
import json
import numpy as np
from PIL import Image, ImageDraw

# Define color values for each standardized label
label_colors = {
    "swimming pool": 1,    # 1 for swimming pools
    "tennis court": 2      # 2 for tennis courts
}

def json_to_png(json_path, output_path):
    """Convert a single JSON file to a single-channel PNG mask image."""
    with open(json_path, 'r') as f:
        data = json.load(f)

    height = data['imageHeight']
    width = data['imageWidth']

    # Initialize mask with background color
    mask = np.zeros((height, width), dtype=np.uint8)

    # Draw each shape in the JSON as a polygon
    for shape in data['shapes']:
        label = shape['label'].lower()  # Convert label to lowercase to standardize
        color = label_colors.get(label, 0)  # Default to 0 (background) if label not found

        if color == 0:
            print(f"Skipping unrecognized label '{label}' in {json_path}")
            continue

        # Convert points to a format suitable for PIL.ImageDraw
        points = shape['points']
        polygon = [(int(point[0]), int(point[1])) for point in points]

        # Draw filled polygon on mask
        img = Image.fromarray(mask)
        draw = ImageDraw.Draw(img)
        draw.polygon(polygon, outline=color, fill=color)
        mask = np.array(img)

    # Save the mask as a PNG file
    Image.fromarray(mask).save(output_path)

# Define input and output directories
input_dir = "/content/drive/MyDrive/json-images"  # Replace with your JSON files folder path
output_dir = "/content/drive/MyDrive/MyProject/mask_outputs3"  # Replace with your output folder path
os.makedirs(output_dir, exist_ok=True)

# Process all JSON files in the directory
for filename in os.listdir(input_dir):
    if filename.endswith(".json"):
        json_path = os.path.join(input_dir, filename)
        png_path = os.path.join(output_dir, filename.replace(".json", ".png"))
        json_to_png(json_path, png_path)

print("Conversion complete! All masks saved to", output_dir)
# Out:
# Skipping unrecognized label 'campus_21' in /content/drive/MyDrive/json-images/campus_scenery_0021.json
# Skipping unrecognized label 'campus_20' in /content/drive/MyDrive/json-images/campus_scenery_0020.json
# Skipping unrecognized label 'campus_10' in /content/drive/MyDrive/json-images/campus_scenery_0010.json
# Skipping unrecognized label 'campus_19' in /content/drive/MyDrive/json-images/campus_scenery_0019.json
# Skipping unrecognized label 'campus_18' in /content/drive/MyDrive/json-images/campus_scenery_0018.json
# Skipping unrecognized label 'campus_17' in /content/drive/MyDrive/json-images/campus_scenery_0017.json
# Skipping unrecognized label 'campus_16' in /content/drive/MyDrive/json-images/campus_scenery_0016.json
# Skipping unrecognized label 'campus_05' in /content/drive/MyDrive/json-images/campus_scenery_0005.json
# Skipping unrecognized label 'campus_04' in /content/drive/MyDrive/json-images/campus_scenery_0004.json
# Skipping unrecognized label 'campus_03' in /content/drive/MyDrive/json-images/campus_scenery_0003.json
# Skipping unrecognized label 'campus_00' in /content/drive/MyDrive/json-images/campus_scenery_0000.json
# Skipping unrecognized label 'campus_15' in /content/drive/MyDrive/json-images/campus_scenery_0015.json
# Skipping unrecognized label 'campus_14' in /content/drive/MyDrive/json-images/campus_scenery_0014.json
# Skipping unrecognized label 'campus_01' in /content/drive/MyDrive/json-images/campus_scenery_0001.json
# Skipping unrecognized label 'campus_13' in /content/drive/MyDrive/json-images/campus_scenery_0013.json
# Skipping unrecognized label 'campus_12' in /content/drive/MyDrive/json-images/campus_scenery_0012.json
# Skipping unrecognized label 'campus_11' in /content/drive/MyDrive/json-images/campus_scenery_0011.json
# Skipping unrecognized label 'campus_06' in /content/drive/MyDrive/json-images/campus_scenery_0006.json
# Skipping unrecognized label 'campus_07' in /content/drive/MyDrive/json-images/campus_scenery_0007.json
# Skipping unrecognized label 'campus_08' in /content/drive/MyDrive/json-images/campus_scenery_0008.json
# Skipping unrecognized label 'campus_09' in /content/drive/MyDrive/json-images/campus_scenery_0009.json
# Skipping unrecognized label 'campus_02' in /content/drive/MyDrive/json-images/campus_scenery_0002.json
# Skipping unrecognized label 'campus_39' in /content/drive/MyDrive/json-images/campus_scenery_0039.json
# Skipping unrecognized label 'campus_38' in /content/drive/MyDrive/json-images/campus_scenery_0038.json
# Skipping unrecognized label 'campus_37' in /content/drive/MyDrive/json-images/campus_scenery_0037.json
# Skipping unrecognized label 'campus_36' in /content/drive/MyDrive/json-images/campus_scenery_0036.json
# Skipping unrecognized label 'campus_35' in /content/drive/MyDrive/json-images/campus_scenery_0035.json
# Skipping unrecognized label 'campus_33' in /content/drive/MyDrive/json-images/campus_scenery_0033.json
# Skipping unrecognized label 'campus_34' in /content/drive/MyDrive/json-images/campus_scenery_0034.json
# Skipping unrecognized label 'campus_32' in /content/drive/MyDrive/json-images/campus_scenery_0032.json
# Skipping unrecognized label 'campus_23' in /content/drive/MyDrive/json-images/campus_scenery_0023.json
# Skipping unrecognized label 'campus_27' in /content/drive/MyDrive/json-images/campus_scenery_0027.json
# Skipping unrecognized label 'campus_31' in /content/drive/MyDrive/json-images/campus_scenery_0031.json
# Skipping unrecognized label 'campus_30' in /content/drive/MyDrive/json-images/campus_scenery_0030.json
# Skipping unrecognized label 'campus_22' in /content/drive/MyDrive/json-images/campus_scenery_0022.json
# Skipping unrecognized label 'campus_25' in /content/drive/MyDrive/json-images/campus_scenery_0025.json
# Skipping unrecognized label 'campus_24' in /content/drive/MyDrive/json-images/campus_scenery_0024.json
# Skipping unrecognized label 'campus_26' in /content/drive/MyDrive/json-images/campus_scenery_0026.json
# Skipping unrecognized label 'campus_28' in /content/drive/MyDrive/json-images/campus_scenery_0028.json
# Skipping unrecognized label 'campus_29' in /content/drive/MyDrive/json-images/campus_scenery_0029.json
# Skipping unrecognized label 'campus_59' in /content/drive/MyDrive/json-images/campus_scenery_0059.json
# Skipping unrecognized label 'campus_58' in /content/drive/MyDrive/json-images/campus_scenery_0058.json
# Skipping unrecognized label 'campus_57' in /content/drive/MyDrive/json-images/campus_scenery_0057.json
# Skipping unrecognized label 'campus_56' in /content/drive/MyDrive/json-images/campus_scenery_0056.json
# Skipping unrecognized label 'campus_55' in /content/drive/MyDrive/json-images/campus_scenery_0055.json
# Skipping unrecognized label 'campus_52' in /content/drive/MyDrive/json-images/campus_scenery_0052.json
# Skipping unrecognized label 'campus_54' in /content/drive/MyDrive/json-images/campus_scenery_0054.json
# Skipping unrecognized label 'campus_53' in /content/drive/MyDrive/json-images/campus_scenery_0053.json
# Skipping unrecognized label 'campus_50' in /content/drive/MyDrive/json-images/campus_scenery_0050.json
# Skipping unrecognized label 'campus_51' in /content/drive/MyDrive/json-images/campus_scenery_0051.json
# Skipping unrecognized label 'campus_48' in /content/drive/MyDrive/json-images/campus_scenery_0048.json
# Skipping unrecognized label 'campus_49' in /content/drive/MyDrive/json-images/campus_scenery_0049.json
# Skipping unrecognized label 'campus_47' in /content/drive/MyDrive/json-images/campus_scenery_0047.json
# Skipping unrecognized label 'campus_40' in /content/drive/MyDrive/json-images/campus_scenery_0040.json
# Skipping unrecognized label 'campus_42' in /content/drive/MyDrive/json-images/campus_scenery_0042.json
# Skipping unrecognized label 'campus_45' in /content/drive/MyDrive/json-images/campus_scenery_0045.json
# Skipping unrecognized label 'campus_41' in /content/drive/MyDrive/json-images/campus_scenery_0041.json
# Skipping unrecognized label 'campus_43' in /content/drive/MyDrive/json-images/campus_scenery_0043.json
# Skipping unrecognized label 'campus_44' in /content/drive/MyDrive/json-images/campus_scenery_0044.json
# Skipping unrecognized label 'campus_46' in /content/drive/MyDrive/json-images/campus_scenery_0046.json
# Skipping unrecognized label 'campus_78' in /content/drive/MyDrive/json-images/campus_scenery_0078.json
# Skipping unrecognized label 'campus_77' in /content/drive/MyDrive/json-images/campus_scenery_0077.json
# Skipping unrecognized label 'campus_76' in /content/drive/MyDrive/json-images/campus_scenery_0076.json
# Skipping unrecognized label 'campus_75' in /content/drive/MyDrive/json-images/campus_scenery_0075.json
# Skipping unrecognized label 'campus_74' in /content/drive/MyDrive/json-images/campus_scenery_0074.json
# Skipping unrecognized label 'campus_73' in /content/drive/MyDrive/json-images/campus_scenery_0073.json
# Skipping unrecognized label 'campus_71' in /content/drive/MyDrive/json-images/campus_scenery_0071.json
# Skipping unrecognized label 'campus_72' in /content/drive/MyDrive/json-images/campus_scenery_0072.json
# Skipping unrecognized label 'campus_70' in /content/drive/MyDrive/json-images/campus_scenery_0070.json
# Skipping unrecognized label 'campus_68' in /content/drive/MyDrive/json-images/campus_scenery_0068.json
# Skipping unrecognized label 'campus_69' in /content/drive/MyDrive/json-images/campus_scenery_0069.json
# Skipping unrecognized label 'campus_67' in /content/drive/MyDrive/json-images/campus_scenery_0067.json
# Skipping unrecognized label 'campus_66' in /content/drive/MyDrive/json-images/campus_scenery_0066.json
# Skipping unrecognized label 'campus_65' in /content/drive/MyDrive/json-images/campus_scenery_0065.json
# Skipping unrecognized label 'campus_64' in /content/drive/MyDrive/json-images/campus_scenery_0064.json
# Skipping unrecognized label 'campus_60' in /content/drive/MyDrive/json-images/campus_scenery_0060.json
# Skipping unrecognized label 'campus_63' in /content/drive/MyDrive/json-images/campus_scenery_0063.json
# Skipping unrecognized label 'campus_62' in /content/drive/MyDrive/json-images/campus_scenery_0062.json
# Skipping unrecognized label 'campus_61' in /content/drive/MyDrive/json-images/campus_scenery_0061.json
# Skipping unrecognized label 'campus_95' in /content/drive/MyDrive/json-images/campus_scenery_0095.json
# Skipping unrecognized label 'campus_94' in /content/drive/MyDrive/json-images/campus_scenery_0094.json
# Skipping unrecognized label 'campus_93' in /content/drive/MyDrive/json-images/campus_scenery_0093.json
# Skipping unrecognized label 'campus_91' in /content/drive/MyDrive/json-images/campus_scenery_0091.json
# Skipping unrecognized label 'campus_92' in /content/drive/MyDrive/json-images/campus_scenery_0092.json
# Skipping unrecognized label 'campus_90' in /content/drive/MyDrive/json-images/campus_scenery_0090.json
# Skipping unrecognized label 'campus_89' in /content/drive/MyDrive/json-images/campus_scenery_0089.json
# Skipping unrecognized label 'campus_88' in /content/drive/MyDrive/json-images/campus_scenery_0088.json
# Skipping unrecognized label 'campus_87' in /content/drive/MyDrive/json-images/campus_scenery_0087.json
# Skipping unrecognized label 'campus_86' in /content/drive/MyDrive/json-images/campus_scenery_0086.json
# Skipping unrecognized label 'campus_85' in /content/drive/MyDrive/json-images/campus_scenery_0085.json
# Skipping unrecognized label 'campus_84' in /content/drive/MyDrive/json-images/campus_scenery_0084.json
# Skipping unrecognized label 'campus_82' in /content/drive/MyDrive/json-images/campus_scenery_0082.json
# Skipping unrecognized label 'campus_83' in /content/drive/MyDrive/json-images/campus_scenery_0083.json
# Skipping unrecognized label 'campus_81' in /content/drive/MyDrive/json-images/campus_scenery_0081.json
# Skipping unrecognized label 'campus_80' in /content/drive/MyDrive/json-images/campus_scenery_0080.json
# Skipping unrecognized label 'campus_79' in /content/drive/MyDrive/json-images/campus_scenery_0079.json
# Skipping unrecognized label 'campus_119' in /content/drive/MyDrive/json-images/campus_scenery_0119.json
# Skipping unrecognized label 'campus_118' in /content/drive/MyDrive/json-images/campus_scenery_0118.json
# Skipping unrecognized label 'campus_117' in /content/drive/MyDrive/json-images/campus_scenery_0117.json
# Skipping unrecognized label 'campus_116' in /content/drive/MyDrive/json-images/campus_scenery_0116.json
# Skipping unrecognized label 'campus_115' in /content/drive/MyDrive/json-images/campus_scenery_0115.json
# Skipping unrecognized label 'campus_114' in /content/drive/MyDrive/json-images/campus_scenery_0114.json
# Skipping unrecognized label 'campus_113' in /content/drive/MyDrive/json-images/campus_scenery_0113.json
# Skipping unrecognized label 'campus_112' in /content/drive/MyDrive/json-images/campus_scenery_0112.json
# Skipping unrecognized label 'campus_111' in /content/drive/MyDrive/json-images/campus_scenery_0111.json
# Skipping unrecognized label 'campus_110' in /content/drive/MyDrive/json-images/campus_scenery_0110.json
# Skipping unrecognized label 'campus_109' in /content/drive/MyDrive/json-images/campus_scenery_0109.json
# Skipping unrecognized label 'campus_108' in /content/drive/MyDrive/json-images/campus_scenery_0108.json
# Skipping unrecognized label 'campus_107' in /content/drive/MyDrive/json-images/campus_scenery_0107.json
# Skipping unrecognized label 'campus_106' in /content/drive/MyDrive/json-images/campus_scenery_0106.json
# Skipping unrecognized label 'campus_105' in /content/drive/MyDrive/json-images/campus_scenery_0105.json
# Skipping unrecognized label 'campus_104' in /content/drive/MyDrive/json-images/campus_scenery_0104.json
# Skipping unrecognized label 'campus_103' in /content/drive/MyDrive/json-images/campus_scenery_0103.json
# Skipping unrecognized label 'campus_102' in /content/drive/MyDrive/json-images/campus_scenery_0102.json
# Skipping unrecognized label 'campus_101' in /content/drive/MyDrive/json-images/campus_scenery_0101.json
# Skipping unrecognized label 'campus_100' in /content/drive/MyDrive/json-images/campus_scenery_0100.json
# Skipping unrecognized label 'campus_99' in /content/drive/MyDrive/json-images/campus_scenery_0099.json
# Skipping unrecognized label 'campus_98' in /content/drive/MyDrive/json-images/campus_scenery_0098.json
# Skipping unrecognized label 'campus_96' in /content/drive/MyDrive/json-images/campus_scenery_0096.json
# Skipping unrecognized label 'campus_97' in /content/drive/MyDrive/json-images/campus_scenery_0097.json
# Skipping unrecognized label 'campus_127' in /content/drive/MyDrive/json-images/campus_scenery_0127.json
# Skipping unrecognized label 'campus_140' in /content/drive/MyDrive/json-images/campus_scenery_0140.json
# Skipping unrecognized label 'campus_139' in /content/drive/MyDrive/json-images/campus_scenery_0139.json
# Skipping unrecognized label 'campus_138' in /content/drive/MyDrive/json-images/campus_scenery_0138.json
# Skipping unrecognized label 'campus_137' in /content/drive/MyDrive/json-images/campus_scenery_0137.json
# Skipping unrecognized label 'campus_136' in /content/drive/MyDrive/json-images/campus_scenery_0136.json
# Skipping unrecognized label 'campus_135' in /content/drive/MyDrive/json-images/campus_scenery_0135.json
# Skipping unrecognized label 'campus_134' in /content/drive/MyDrive/json-images/campus_scenery_0134.json
# Skipping unrecognized label 'campus_133' in /content/drive/MyDrive/json-images/campus_scenery_0133.json
# Skipping unrecognized label 'campus_132' in /content/drive/MyDrive/json-images/campus_scenery_0132.json
# Skipping unrecognized label 'campus_130' in /content/drive/MyDrive/json-images/campus_scenery_0130.json
# Skipping unrecognized label 'campus_131' in /content/drive/MyDrive/json-images/campus_scenery_0131.json
# Skipping unrecognized label 'campus_129' in /content/drive/MyDrive/json-images/campus_scenery_0129.json
# Skipping unrecognized label 'campus_128' in /content/drive/MyDrive/json-images/campus_scenery_0128.json
# Skipping unrecognized label 'campus_125' in /content/drive/MyDrive/json-images/campus_scenery_0125.json
# Skipping unrecognized label 'campus_126' in /content/drive/MyDrive/json-images/campus_scenery_0126.json
# Skipping unrecognized label 'campus_123' in /content/drive/MyDrive/json-images/campus_scenery_0123.json
# Skipping unrecognized label 'campus_124' in /content/drive/MyDrive/json-images/campus_scenery_0124.json
# Skipping unrecognized label 'campus_121' in /content/drive/MyDrive/json-images/campus_scenery_0121.json
# Skipping unrecognized label 'campus_122' in /content/drive/MyDrive/json-images/campus_scenery_0122.json
# Skipping unrecognized label 'campus_120' in /content/drive/MyDrive/json-images/campus_scenery_0120.json
# Skipping unrecognized label 'campus_194' in /content/drive/MyDrive/json-images/campus_scenery_0194.json
# Skipping unrecognized label 'campus_193' in /content/drive/MyDrive/json-images/campus_scenery_0193.json
# Skipping unrecognized label 'campus_192' in /content/drive/MyDrive/json-images/campus_scenery_0192.json
# Skipping unrecognized label 'campus_191' in /content/drive/MyDrive/json-images/campus_scenery_0191.json
# Skipping unrecognized label 'campus_190' in /content/drive/MyDrive/json-images/campus_scenery_0190.json
# Skipping unrecognized label 'campus_189' in /content/drive/MyDrive/json-images/campus_scenery_0189.json
# Skipping unrecognized label 'campus_188' in /content/drive/MyDrive/json-images/campus_scenery_0188.json
# Skipping unrecognized label 'campus_187' in /content/drive/MyDrive/json-images/campus_scenery_0187.json
# Skipping unrecognized label 'campus_186' in /content/drive/MyDrive/json-images/campus_scenery_0186.json
# Skipping unrecognized label 'campus_172' in /content/drive/MyDrive/json-images/campus_scenery_0172.json
# Skipping unrecognized label 'campus_171' in /content/drive/MyDrive/json-images/campus_scenery_0171.json
# Skipping unrecognized label 'campus_170' in /content/drive/MyDrive/json-images/campus_scenery_0170.json
# Skipping unrecognized label 'campus_183' in /content/drive/MyDrive/json-images/campus_scenery_0183.json
# Skipping unrecognized label 'campus_177' in /content/drive/MyDrive/json-images/campus_scenery_0177.json
# Skipping unrecognized label 'campus_180' in /content/drive/MyDrive/json-images/campus_scenery_0180.json
# Skipping unrecognized label 'campus_175' in /content/drive/MyDrive/json-images/campus_scenery_0175.json
# Skipping unrecognized label 'campus_182' in /content/drive/MyDrive/json-images/campus_scenery_0182.json
# Skipping unrecognized label 'campus_173' in /content/drive/MyDrive/json-images/campus_scenery_0173.json
# Skipping unrecognized label 'campus_181' in /content/drive/MyDrive/json-images/campus_scenery_0181.json
# Skipping unrecognized label 'campus_169' in /content/drive/MyDrive/json-images/campus_scenery_0169.json
# Skipping unrecognized label 'campus_179' in /content/drive/MyDrive/json-images/campus_scenery_0179.json
# Skipping unrecognized label 'campus_178' in /content/drive/MyDrive/json-images/campus_scenery_0178.json
# Skipping unrecognized label 'campus_168' in /content/drive/MyDrive/json-images/campus_scenery_0168.json
# Skipping unrecognized label 'campus_174' in /content/drive/MyDrive/json-images/campus_scenery_0174.json
# Skipping unrecognized label 'campus_176' in /content/drive/MyDrive/json-images/campus_scenery_0176.json
# Skipping unrecognized label 'campus_185' in /content/drive/MyDrive/json-images/campus_scenery_0185.json
# Skipping unrecognized label 'campus_184' in /content/drive/MyDrive/json-images/campus_scenery_0184.json
# Skipping unrecognized label 'campus_161' in /content/drive/MyDrive/json-images/campus_scenery_0161.json
# Skipping unrecognized label 'campus_167' in /content/drive/MyDrive/json-images/campus_scenery_0167.json
# Skipping unrecognized label 'campus_150' in /content/drive/MyDrive/json-images/campus_scenery_0150.json
# Skipping unrecognized label 'campus_154' in /content/drive/MyDrive/json-images/campus_scenery_0154.json
# Skipping unrecognized label 'campus_160' in /content/drive/MyDrive/json-images/campus_scenery_0160.json
# Skipping unrecognized label 'campus_164' in /content/drive/MyDrive/json-images/campus_scenery_0164.json
# Skipping unrecognized label 'campus_166' in /content/drive/MyDrive/json-images/campus_scenery_0166.json
# Skipping unrecognized label 'campus_153' in /content/drive/MyDrive/json-images/campus_scenery_0153.json
# Skipping unrecognized label 'campus_142' in /content/drive/MyDrive/json-images/campus_scenery_0142.json
# Skipping unrecognized label 'campus_143' in /content/drive/MyDrive/json-images/campus_scenery_0143.json
# Skipping unrecognized label 'campus_163' in /content/drive/MyDrive/json-images/campus_scenery_0163.json
# Skipping unrecognized label 'campus_141' in /content/drive/MyDrive/json-images/campus_scenery_0141.json
# Skipping unrecognized label 'campus_149' in /content/drive/MyDrive/json-images/campus_scenery_0149.json
# Skipping unrecognized label 'campus_148' in /content/drive/MyDrive/json-images/campus_scenery_0148.json
# Skipping unrecognized label 'campus_165' in /content/drive/MyDrive/json-images/campus_scenery_0165.json
# Skipping unrecognized label 'campus_151' in /content/drive/MyDrive/json-images/campus_scenery_0151.json
# Skipping unrecognized label 'campus_162' in /content/drive/MyDrive/json-images/campus_scenery_0162.json
# Skipping unrecognized label 'campus_144' in /content/drive/MyDrive/json-images/campus_scenery_0144.json
# Skipping unrecognized label 'campus_147' in /content/drive/MyDrive/json-images/campus_scenery_0147.json
# Skipping unrecognized label 'campus_145' in /content/drive/MyDrive/json-images/campus_scenery_0145.json
# Skipping unrecognized label 'campus_146' in /content/drive/MyDrive/json-images/campus_scenery_0146.json
# Skipping unrecognized label 'campus_155' in /content/drive/MyDrive/json-images/campus_scenery_0155.json
# Skipping unrecognized label 'campus_156' in /content/drive/MyDrive/json-images/campus_scenery_0156.json
# Skipping unrecognized label 'campus_159' in /content/drive/MyDrive/json-images/campus_scenery_0159.json
# Skipping unrecognized label 'campus_157' in /content/drive/MyDrive/json-images/campus_scenery_0157.json
# Skipping unrecognized label 'campus_158' in /content/drive/MyDrive/json-images/campus_scenery_0158.json
# Skipping unrecognized label 'campus_152' in /content/drive/MyDrive/json-images/campus_scenery_0152.json
# Skipping unrecognized label 'campus_195' in /content/drive/MyDrive/json-images/campus_scenery_0195.json
# Skipping unrecognized label 'campus_196' in /content/drive/MyDrive/json-images/campus_scenery_0196.json
# Skipping unrecognized label 'campus_199' in /content/drive/MyDrive/json-images/campus_scenery_0199.json
# Skipping unrecognized label 'campus_197' in /content/drive/MyDrive/json-images/campus_scenery_0197.json
# Skipping unrecognized label 'campus_198' in /content/drive/MyDrive/json-images/campus_scenery_0198.json
# Conversion complete! All masks saved to /content/drive/MyDrive/MyProject/mask_outputs3

# %%
import os
import json
import numpy as np
from PIL import Image, ImageDraw

def labelme_json_to_mask(json_path, output_path):
    """Convert LabelMe JSON file to binary mask"""
    # Read JSON file
    with open(json_path, 'r') as f:
        data = json.load(f)

    # Get image dimensions from JSON
    height = data['imageHeight']
    width = data['imageWidth']

    # Create empty mask
    mask = np.zeros((height, width), dtype=np.uint8)

    # Create PIL Image and Draw objects
    img = Image.fromarray(mask)
    draw = ImageDraw.Draw(img)

    # Process each shape in the JSON
    for shape in data['shapes']:
        # Get points from the shape
        points = shape['points']
        # Convert points to integer tuples
        points = [(int(x), int(y)) for x, y in points]

        # Draw the polygon with white color (255)
        draw.polygon(points, fill=255)

    # Convert back to numpy array
    mask = np.array(img)

    # Save the mask
    Image.fromarray(mask).save(output_path)
    print(f"Saved mask to {output_path}")

    # Verify mask isn't empty
    if np.max(mask) == 0:
        print(f"Warning: Mask for {os.path.basename(json_path)} is all black!")

    return mask

# Set your directories here
json_dir = "/content/drive/MyDrive/json-images"  # Change this to your JSON directory
output_dir = "/content/drive/MyDrive/MyProject/mask_outputs4"     # Change this to where you want to save masks

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Process all JSON files
for filename in os.listdir(json_dir):
    if filename.endswith('.json'):
        json_path = os.path.join(json_dir, filename)
        # Create mask filename - replace .json with _mask.png
        mask_filename = filename.replace('.json', '_mask.png')
        mask_path = os.path.join(output_dir, mask_filename)

        try:
            mask = labelme_json_to_mask(json_path, mask_path)
            print(f"Successfully processed {filename}")
        except Exception as e:
            print(f"Error processing {filename}: {str(e)}")

print("Conversion complete!")

# Optional: Display a few masks to verify
def display_mask(mask_path):
    """Display a mask to verify it's not all black"""
    mask = Image.open(mask_path)
    if np.all(np.array(mask) == 0):
        print(f"Warning: {mask_path} is completely black!")
    else:
        print(f"Mask {mask_path} contains annotations")
    return mask
# Out:
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0021_mask.png
# Successfully processed campus_scenery_0021.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0020_mask.png
# Successfully processed campus_scenery_0020.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0010_mask.png
# Successfully processed campus_scenery_0010.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0019_mask.png
# Successfully processed campus_scenery_0019.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0018_mask.png
# Successfully processed campus_scenery_0018.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0017_mask.png
# Successfully processed campus_scenery_0017.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0016_mask.png
# Successfully processed campus_scenery_0016.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0005_mask.png
# Successfully processed campus_scenery_0005.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0004_mask.png
# Successfully processed campus_scenery_0004.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0003_mask.png
# Successfully processed campus_scenery_0003.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0000_mask.png
# Successfully processed campus_scenery_0000.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0015_mask.png
# Successfully processed campus_scenery_0015.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0014_mask.png
# Successfully processed campus_scenery_0014.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0001_mask.png
# Successfully processed campus_scenery_0001.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0013_mask.png
# Successfully processed campus_scenery_0013.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0012_mask.png
# Successfully processed campus_scenery_0012.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0011_mask.png
# Successfully processed campus_scenery_0011.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0006_mask.png
# Successfully processed campus_scenery_0006.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0007_mask.png
# Successfully processed campus_scenery_0007.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0008_mask.png
# Successfully processed campus_scenery_0008.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0009_mask.png
# Successfully processed campus_scenery_0009.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0002_mask.png
# Successfully processed campus_scenery_0002.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0039_mask.png
# Successfully processed campus_scenery_0039.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0038_mask.png
# Successfully processed campus_scenery_0038.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0037_mask.png
# Successfully processed campus_scenery_0037.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0036_mask.png
# Successfully processed campus_scenery_0036.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0035_mask.png
# Successfully processed campus_scenery_0035.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0033_mask.png
# Successfully processed campus_scenery_0033.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0034_mask.png
# Successfully processed campus_scenery_0034.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0032_mask.png
# Successfully processed campus_scenery_0032.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0023_mask.png
# Successfully processed campus_scenery_0023.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0027_mask.png
# Successfully processed campus_scenery_0027.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0031_mask.png
# Successfully processed campus_scenery_0031.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0030_mask.png
# Successfully processed campus_scenery_0030.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0022_mask.png
# Successfully processed campus_scenery_0022.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0025_mask.png
# Successfully processed campus_scenery_0025.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0024_mask.png
# Successfully processed campus_scenery_0024.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0026_mask.png
# Successfully processed campus_scenery_0026.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0028_mask.png
# Successfully processed campus_scenery_0028.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0029_mask.png
# Successfully processed campus_scenery_0029.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0059_mask.png
# Successfully processed campus_scenery_0059.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0058_mask.png
# Successfully processed campus_scenery_0058.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0057_mask.png
# Successfully processed campus_scenery_0057.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0056_mask.png
# Successfully processed campus_scenery_0056.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0055_mask.png
# Successfully processed campus_scenery_0055.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0052_mask.png
# Successfully processed campus_scenery_0052.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0054_mask.png
# Successfully processed campus_scenery_0054.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0053_mask.png
# Successfully processed campus_scenery_0053.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0050_mask.png
# Successfully processed campus_scenery_0050.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0051_mask.png
# Successfully processed campus_scenery_0051.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0048_mask.png
# Successfully processed campus_scenery_0048.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0049_mask.png
# Successfully processed campus_scenery_0049.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0047_mask.png
# Successfully processed campus_scenery_0047.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0040_mask.png
# Successfully processed campus_scenery_0040.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0042_mask.png
# Successfully processed campus_scenery_0042.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0045_mask.png
# Successfully processed campus_scenery_0045.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0041_mask.png
# Successfully processed campus_scenery_0041.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0043_mask.png
# Successfully processed campus_scenery_0043.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0044_mask.png
# Successfully processed campus_scenery_0044.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0046_mask.png
# Successfully processed campus_scenery_0046.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0078_mask.png
# Successfully processed campus_scenery_0078.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0077_mask.png
# Successfully processed campus_scenery_0077.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0076_mask.png
# Successfully processed campus_scenery_0076.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0075_mask.png
# Successfully processed campus_scenery_0075.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0074_mask.png
# Successfully processed campus_scenery_0074.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0073_mask.png
# Successfully processed campus_scenery_0073.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0071_mask.png
# Successfully processed campus_scenery_0071.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0072_mask.png
# Successfully processed campus_scenery_0072.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0070_mask.png
# Successfully processed campus_scenery_0070.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0068_mask.png
# Successfully processed campus_scenery_0068.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0069_mask.png
# Successfully processed campus_scenery_0069.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0067_mask.png
# Successfully processed campus_scenery_0067.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0066_mask.png
# Successfully processed campus_scenery_0066.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0065_mask.png
# Successfully processed campus_scenery_0065.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0064_mask.png
# Successfully processed campus_scenery_0064.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0060_mask.png
# Successfully processed campus_scenery_0060.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0063_mask.png
# Successfully processed campus_scenery_0063.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0062_mask.png
# Successfully processed campus_scenery_0062.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0061_mask.png
# Successfully processed campus_scenery_0061.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0095_mask.png
# Successfully processed campus_scenery_0095.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0094_mask.png
# Successfully processed campus_scenery_0094.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0093_mask.png
# Successfully processed campus_scenery_0093.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0091_mask.png
# Successfully processed campus_scenery_0091.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0092_mask.png
# Successfully processed campus_scenery_0092.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0090_mask.png
# Successfully processed campus_scenery_0090.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0089_mask.png
# Successfully processed campus_scenery_0089.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0088_mask.png
# Successfully processed campus_scenery_0088.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0087_mask.png
# Successfully processed campus_scenery_0087.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0086_mask.png
# Successfully processed campus_scenery_0086.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0085_mask.png
# Successfully processed campus_scenery_0085.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0084_mask.png
# Successfully processed campus_scenery_0084.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0082_mask.png
# Successfully processed campus_scenery_0082.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0083_mask.png
# Successfully processed campus_scenery_0083.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0081_mask.png
# Successfully processed campus_scenery_0081.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0080_mask.png
# Successfully processed campus_scenery_0080.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0079_mask.png
# Successfully processed campus_scenery_0079.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0119_mask.png
# Successfully processed campus_scenery_0119.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0118_mask.png
# Successfully processed campus_scenery_0118.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0117_mask.png
# Successfully processed campus_scenery_0117.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0116_mask.png
# Successfully processed campus_scenery_0116.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0115_mask.png
# Successfully processed campus_scenery_0115.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0114_mask.png
# Successfully processed campus_scenery_0114.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0113_mask.png
# Successfully processed campus_scenery_0113.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0112_mask.png
# Successfully processed campus_scenery_0112.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0111_mask.png
# Successfully processed campus_scenery_0111.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0110_mask.png
# Successfully processed campus_scenery_0110.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0109_mask.png
# Successfully processed campus_scenery_0109.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0108_mask.png
# Successfully processed campus_scenery_0108.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0107_mask.png
# Successfully processed campus_scenery_0107.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0106_mask.png
# Successfully processed campus_scenery_0106.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0105_mask.png
# Successfully processed campus_scenery_0105.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0104_mask.png
# Successfully processed campus_scenery_0104.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0103_mask.png
# Successfully processed campus_scenery_0103.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0102_mask.png
# Successfully processed campus_scenery_0102.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0101_mask.png
# Successfully processed campus_scenery_0101.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0100_mask.png
# Successfully processed campus_scenery_0100.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0099_mask.png
# Successfully processed campus_scenery_0099.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0098_mask.png
# Successfully processed campus_scenery_0098.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0096_mask.png
# Successfully processed campus_scenery_0096.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0097_mask.png
# Successfully processed campus_scenery_0097.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0127_mask.png
# Successfully processed campus_scenery_0127.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0140_mask.png
# Successfully processed campus_scenery_0140.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0139_mask.png
# Successfully processed campus_scenery_0139.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0138_mask.png
# Successfully processed campus_scenery_0138.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0137_mask.png
# Successfully processed campus_scenery_0137.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0136_mask.png
# Successfully processed campus_scenery_0136.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0135_mask.png
# Successfully processed campus_scenery_0135.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0134_mask.png
# Successfully processed campus_scenery_0134.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0133_mask.png
# Successfully processed campus_scenery_0133.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0132_mask.png
# Successfully processed campus_scenery_0132.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0130_mask.png
# Successfully processed campus_scenery_0130.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0131_mask.png
# Successfully processed campus_scenery_0131.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0129_mask.png
# Successfully processed campus_scenery_0129.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0128_mask.png
# Successfully processed campus_scenery_0128.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0125_mask.png
# Successfully processed campus_scenery_0125.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0126_mask.png
# Successfully processed campus_scenery_0126.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0123_mask.png
# Successfully processed campus_scenery_0123.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0124_mask.png
# Successfully processed campus_scenery_0124.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0121_mask.png
# Successfully processed campus_scenery_0121.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0122_mask.png
# Successfully processed campus_scenery_0122.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0120_mask.png
# Successfully processed campus_scenery_0120.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0194_mask.png
# Successfully processed campus_scenery_0194.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0193_mask.png
# Successfully processed campus_scenery_0193.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0192_mask.png
# Successfully processed campus_scenery_0192.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0191_mask.png
# Successfully processed campus_scenery_0191.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0190_mask.png
# Successfully processed campus_scenery_0190.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0189_mask.png
# Successfully processed campus_scenery_0189.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0188_mask.png
# Successfully processed campus_scenery_0188.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0187_mask.png
# Successfully processed campus_scenery_0187.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0186_mask.png
# Successfully processed campus_scenery_0186.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0172_mask.png
# Successfully processed campus_scenery_0172.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0171_mask.png
# Successfully processed campus_scenery_0171.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0170_mask.png
# Successfully processed campus_scenery_0170.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0183_mask.png
# Successfully processed campus_scenery_0183.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0177_mask.png
# Successfully processed campus_scenery_0177.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0180_mask.png
# Successfully processed campus_scenery_0180.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0175_mask.png
# Successfully processed campus_scenery_0175.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0182_mask.png
# Successfully processed campus_scenery_0182.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0173_mask.png
# Successfully processed campus_scenery_0173.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0181_mask.png
# Successfully processed campus_scenery_0181.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0169_mask.png
# Successfully processed campus_scenery_0169.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0179_mask.png
# Successfully processed campus_scenery_0179.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0178_mask.png
# Successfully processed campus_scenery_0178.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0168_mask.png
# Successfully processed campus_scenery_0168.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0174_mask.png
# Successfully processed campus_scenery_0174.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0176_mask.png
# Successfully processed campus_scenery_0176.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0185_mask.png
# Successfully processed campus_scenery_0185.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0184_mask.png
# Successfully processed campus_scenery_0184.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0161_mask.png
# Successfully processed campus_scenery_0161.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0167_mask.png
# Successfully processed campus_scenery_0167.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0150_mask.png
# Successfully processed campus_scenery_0150.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0154_mask.png
# Successfully processed campus_scenery_0154.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0160_mask.png
# Successfully processed campus_scenery_0160.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0164_mask.png
# Successfully processed campus_scenery_0164.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0166_mask.png
# Successfully processed campus_scenery_0166.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0153_mask.png
# Successfully processed campus_scenery_0153.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0142_mask.png
# Successfully processed campus_scenery_0142.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0143_mask.png
# Successfully processed campus_scenery_0143.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0163_mask.png
# Successfully processed campus_scenery_0163.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0141_mask.png
# Successfully processed campus_scenery_0141.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0149_mask.png
# Successfully processed campus_scenery_0149.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0148_mask.png
# Successfully processed campus_scenery_0148.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0165_mask.png
# Successfully processed campus_scenery_0165.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0151_mask.png
# Successfully processed campus_scenery_0151.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0162_mask.png
# Successfully processed campus_scenery_0162.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0144_mask.png
# Successfully processed campus_scenery_0144.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0147_mask.png
# Successfully processed campus_scenery_0147.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0145_mask.png
# Successfully processed campus_scenery_0145.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0146_mask.png
# Successfully processed campus_scenery_0146.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0155_mask.png
# Successfully processed campus_scenery_0155.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0156_mask.png
# Successfully processed campus_scenery_0156.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0159_mask.png
# Successfully processed campus_scenery_0159.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0157_mask.png
# Successfully processed campus_scenery_0157.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0158_mask.png
# Successfully processed campus_scenery_0158.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0152_mask.png
# Successfully processed campus_scenery_0152.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0195_mask.png
# Successfully processed campus_scenery_0195.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0196_mask.png
# Successfully processed campus_scenery_0196.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0199_mask.png
# Successfully processed campus_scenery_0199.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0197_mask.png
# Successfully processed campus_scenery_0197.json
# Saved mask to /content/drive/MyDrive/MyProject/mask_outputs4/campus_scenery_0198_mask.png
# Successfully processed campus_scenery_0198.json
# Conversion complete!

# %%
import os
import json
import numpy as np
from PIL import Image, ImageDraw

def labelme_json_to_colored_mask(json_path, output_path):
    """Convert LabelMe JSON file to colored mask with:
    - Blue (0, 0, 255) for swimming pool
    - Green (0, 255, 0) for tennis court
    - Black (0, 0, 0) for background
    """
    # Read JSON file
    with open(json_path, 'r') as f:
        data = json.load(f)

    # Get image dimensions
    height = data['imageHeight']
    width = data['imageWidth']

    # Create empty RGB mask (black background)
    mask = np.zeros((height, width, 3), dtype=np.uint8)

    # Color mapping
    colors = {
        'swimming pool': (0, 0, 255),  # Blue
        'tennis court': (0, 255, 0)    # Green
    }

    # Process each shape in the JSON
    for shape in data['shapes']:
        label = shape['label'].lower()  # Convert to lowercase for consistency
        if label in colors:
            # Get points and color for this shape
            points = shape['points']
            color = colors[label]

            # Convert points to integer coordinates
            points = [(int(x), int(y)) for x, y in points]

            # Create temporary mask for this shape
            temp_mask = Image.new('RGB', (width, height), (0, 0, 0))
            draw = ImageDraw.Draw(temp_mask)

            # Draw the polygon with appropriate color
            draw.polygon(points, fill=color)

            # Convert to numpy array and combine with main mask
            shape_mask = np.array(temp_mask)
            mask = np.maximum(mask, shape_mask)

    # Save the colored mask
    Image.fromarray(mask).save(output_path)

    # Verify mask isn't empty
    if np.all(mask == 0):
        print(f"Warning: Mask for {os.path.basename(json_path)} is all black!")

    return mask

# Set your directories here
json_dir = "/content/drive/MyDrive/json-images"  # Change this to your JSON directory
output_dir = "/content/drive/MyDrive/MyProject/mask_outputs5"     # Change this to where you want to save masks

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Process all JSON files
for filename in os.listdir(json_dir):
    if filename.endswith('.json'):
        json_path = os.path.join(json_dir, filename)
        # Create mask filename - replace .json with _mask.png
        mask_filename = filename.replace('.json', '_colored_mask.png')
        mask_path = os.path.join(output_dir, mask_filename)

        try:
            mask = labelme_json_to_colored_mask(json_path, mask_path)
            print(f"Successfully processed {filename}")
        except Exception as e:
            print(f"Error processing {filename}: {str(e)}")

print("Conversion complete!")

# Optional: Function to verify masks
def verify_colored_mask(mask_path):
    """Verify that mask contains the expected colors"""
    mask = np.array(Image.open(mask_path))

    has_swimming_pool = np.any(np.all(mask == [0, 0, 255], axis=2))
    has_tennis_court = np.any(np.all(mask == [0, 255, 0], axis=2))

    print(f"Mask {os.path.basename(mask_path)}:")
    print(f"  - Contains swimming pool: {has_swimming_pool}")
    print(f"  - Contains tennis court: {has_tennis_court}")

    if not (has_swimming_pool or has_tennis_court):
        print("  WARNING: Mask contains neither class!")

# Verify all generated masks
for filename in os.listdir(output_dir):
    if filename.endswith('_colored_mask.png'):
        verify_colored_mask(os.path.join(output_dir, filename))
# Out:
# Warning: Mask for campus_scenery_0021.json is all black!
# Successfully processed campus_scenery_0021.json
# Warning: Mask for campus_scenery_0020.json is all black!
# Successfully processed campus_scenery_0020.json
# Warning: Mask for campus_scenery_0010.json is all black!
# Successfully processed campus_scenery_0010.json
# Warning: Mask for campus_scenery_0019.json is all black!
# Successfully processed campus_scenery_0019.json
# Warning: Mask for campus_scenery_0018.json is all black!
# Successfully processed campus_scenery_0018.json
# Warning: Mask for campus_scenery_0017.json is all black!
# Successfully processed campus_scenery_0017.json
# Warning: Mask for campus_scenery_0016.json is all black!
# Successfully processed campus_scenery_0016.json
# Warning: Mask for campus_scenery_0005.json is all black!
# Successfully processed campus_scenery_0005.json
# Warning: Mask for campus_scenery_0004.json is all black!
# Successfully processed campus_scenery_0004.json
# Warning: Mask for campus_scenery_0003.json is all black!
# Successfully processed campus_scenery_0003.json
# Warning: Mask for campus_scenery_0000.json is all black!
# Successfully processed campus_scenery_0000.json
# Warning: Mask for campus_scenery_0015.json is all black!
# Successfully processed campus_scenery_0015.json
# Warning: Mask for campus_scenery_0014.json is all black!
# Successfully processed campus_scenery_0014.json
# Warning: Mask for campus_scenery_0001.json is all black!
# Successfully processed campus_scenery_0001.json
# Warning: Mask for campus_scenery_0013.json is all black!
# Successfully processed campus_scenery_0013.json
# Warning: Mask for campus_scenery_0012.json is all black!
# Successfully processed campus_scenery_0012.json
# Warning: Mask for campus_scenery_0011.json is all black!
# Successfully processed campus_scenery_0011.json
# Warning: Mask for campus_scenery_0006.json is all black!
# Successfully processed campus_scenery_0006.json
# Warning: Mask for campus_scenery_0007.json is all black!
# Successfully processed campus_scenery_0007.json
# Warning: Mask for campus_scenery_0008.json is all black!
# Successfully processed campus_scenery_0008.json
# Warning: Mask for campus_scenery_0009.json is all black!
# Successfully processed campus_scenery_0009.json
# Warning: Mask for campus_scenery_0002.json is all black!
# Successfully processed campus_scenery_0002.json
# Warning: Mask for campus_scenery_0039.json is all black!
# Successfully processed campus_scenery_0039.json
# Warning: Mask for campus_scenery_0038.json is all black!
# Successfully processed campus_scenery_0038.json
# Warning: Mask for campus_scenery_0037.json is all black!
# Successfully processed campus_scenery_0037.json
# Warning: Mask for campus_scenery_0036.json is all black!
# Successfully processed campus_scenery_0036.json
# Warning: Mask for campus_scenery_0035.json is all black!
# Successfully processed campus_scenery_0035.json
# Warning: Mask for campus_scenery_0033.json is all black!
# Successfully processed campus_scenery_0033.json
# Warning: Mask for campus_scenery_0034.json is all black!
# Successfully processed campus_scenery_0034.json
# Warning: Mask for campus_scenery_0032.json is all black!
# Successfully processed campus_scenery_0032.json
# Warning: Mask for campus_scenery_0023.json is all black!
# Successfully processed campus_scenery_0023.json
# Warning: Mask for campus_scenery_0027.json is all black!
# Successfully processed campus_scenery_0027.json
# Warning: Mask for campus_scenery_0031.json is all black!
# Successfully processed campus_scenery_0031.json
# Warning: Mask for campus_scenery_0030.json is all black!
# Successfully processed campus_scenery_0030.json
# Warning: Mask for campus_scenery_0022.json is all black!
# Successfully processed campus_scenery_0022.json
# Warning: Mask for campus_scenery_0025.json is all black!
# Successfully processed campus_scenery_0025.json
# Warning: Mask for campus_scenery_0024.json is all black!
# Successfully processed campus_scenery_0024.json
# Warning: Mask for campus_scenery_0026.json is all black!
# Successfully processed campus_scenery_0026.json
# Warning: Mask for campus_scenery_0028.json is all black!
# Successfully processed campus_scenery_0028.json
# Warning: Mask for campus_scenery_0029.json is all black!
# Successfully processed campus_scenery_0029.json
# Warning: Mask for campus_scenery_0059.json is all black!
# Successfully processed campus_scenery_0059.json
# Warning: Mask for campus_scenery_0058.json is all black!
# Successfully processed campus_scenery_0058.json
# Warning: Mask for campus_scenery_0057.json is all black!
# Successfully processed campus_scenery_0057.json
# Warning: Mask for campus_scenery_0056.json is all black!
# Successfully processed campus_scenery_0056.json
# Warning: Mask for campus_scenery_0055.json is all black!
# Successfully processed campus_scenery_0055.json
# Warning: Mask for campus_scenery_0052.json is all black!
# Successfully processed campus_scenery_0052.json
# Warning: Mask for campus_scenery_0054.json is all black!
# Successfully processed campus_scenery_0054.json
# Warning: Mask for campus_scenery_0053.json is all black!
# Successfully processed campus_scenery_0053.json
# Warning: Mask for campus_scenery_0050.json is all black!
# Successfully processed campus_scenery_0050.json
# Warning: Mask for campus_scenery_0051.json is all black!
# Successfully processed campus_scenery_0051.json
# Warning: Mask for campus_scenery_0048.json is all black!
# Successfully processed campus_scenery_0048.json
# Warning: Mask for campus_scenery_0049.json is all black!
# Successfully processed campus_scenery_0049.json
# Warning: Mask for campus_scenery_0047.json is all black!
# Successfully processed campus_scenery_0047.json
# Warning: Mask for campus_scenery_0040.json is all black!
# Successfully processed campus_scenery_0040.json
# Warning: Mask for campus_scenery_0042.json is all black!
# Successfully processed campus_scenery_0042.json
# Warning: Mask for campus_scenery_0045.json is all black!
# Successfully processed campus_scenery_0045.json
# Warning: Mask for campus_scenery_0041.json is all black!
# Successfully processed campus_scenery_0041.json
# Warning: Mask for campus_scenery_0043.json is all black!
# Successfully processed campus_scenery_0043.json
# Warning: Mask for campus_scenery_0044.json is all black!
# Successfully processed campus_scenery_0044.json
# Warning: Mask for campus_scenery_0046.json is all black!
# Successfully processed campus_scenery_0046.json
# Warning: Mask for campus_scenery_0078.json is all black!
# Successfully processed campus_scenery_0078.json
# Warning: Mask for campus_scenery_0077.json is all black!
# Successfully processed campus_scenery_0077.json
# Warning: Mask for campus_scenery_0076.json is all black!
# Successfully processed campus_scenery_0076.json
# Warning: Mask for campus_scenery_0075.json is all black!
# Successfully processed campus_scenery_0075.json
# Warning: Mask for campus_scenery_0074.json is all black!
# Successfully processed campus_scenery_0074.json
# Warning: Mask for campus_scenery_0073.json is all black!
# Successfully processed campus_scenery_0073.json
# Warning: Mask for campus_scenery_0071.json is all black!
# Successfully processed campus_scenery_0071.json
# Warning: Mask for campus_scenery_0072.json is all black!
# Successfully processed campus_scenery_0072.json
# Warning: Mask for campus_scenery_0070.json is all black!
# Successfully processed campus_scenery_0070.json
# Warning: Mask for campus_scenery_0068.json is all black!
# Successfully processed campus_scenery_0068.json
# Warning: Mask for campus_scenery_0069.json is all black!
# Successfully processed campus_scenery_0069.json
# Warning: Mask for campus_scenery_0067.json is all black!
# Successfully processed campus_scenery_0067.json
# Warning: Mask for campus_scenery_0066.json is all black!
# Successfully processed campus_scenery_0066.json
# Warning: Mask for campus_scenery_0065.json is all black!
# Successfully processed campus_scenery_0065.json
# Warning: Mask for campus_scenery_0064.json is all black!
# Successfully processed campus_scenery_0064.json
# Warning: Mask for campus_scenery_0060.json is all black!
# Successfully processed campus_scenery_0060.json
# Warning: Mask for campus_scenery_0063.json is all black!
# Successfully processed campus_scenery_0063.json
# Warning: Mask for campus_scenery_0062.json is all black!
# Successfully processed campus_scenery_0062.json
# Warning: Mask for campus_scenery_0061.json is all black!
# Successfully processed campus_scenery_0061.json
# Warning: Mask for campus_scenery_0095.json is all black!
# Successfully processed campus_scenery_0095.json
# Warning: Mask for campus_scenery_0094.json is all black!
# Successfully processed campus_scenery_0094.json
# Warning: Mask for campus_scenery_0093.json is all black!
# Successfully processed campus_scenery_0093.json
# Warning: Mask for campus_scenery_0091.json is all black!
# Successfully processed campus_scenery_0091.json
# Warning: Mask for campus_scenery_0092.json is all black!
# Successfully processed campus_scenery_0092.json
# Warning: Mask for campus_scenery_0090.json is all black!
# Successfully processed campus_scenery_0090.json
# Warning: Mask for campus_scenery_0089.json is all black!
# Successfully processed campus_scenery_0089.json
# Warning: Mask for campus_scenery_0088.json is all black!
# Successfully processed campus_scenery_0088.json
# Warning: Mask for campus_scenery_0087.json is all black!
# Successfully processed campus_scenery_0087.json
# Warning: Mask for campus_scenery_0086.json is all black!
# Successfully processed campus_scenery_0086.json
# Warning: Mask for campus_scenery_0085.json is all black!
# Successfully processed campus_scenery_0085.json
# Warning: Mask for campus_scenery_0084.json is all black!
# Successfully processed campus_scenery_0084.json
# Warning: Mask for campus_scenery_0082.json is all black!
# Successfully processed campus_scenery_0082.json
# Warning: Mask for campus_scenery_0083.json is all black!
# Successfully processed campus_scenery_0083.json
# Warning: Mask for campus_scenery_0081.json is all black!
# Successfully processed campus_scenery_0081.json
# Warning: Mask for campus_scenery_0080.json is all black!
# Successfully processed campus_scenery_0080.json
# Warning: Mask for campus_scenery_0079.json is all black!
# Successfully processed campus_scenery_0079.json
# Warning: Mask for campus_scenery_0119.json is all black!
# Successfully processed campus_scenery_0119.json
# Warning: Mask for campus_scenery_0118.json is all black!
# Successfully processed campus_scenery_0118.json
# Warning: Mask for campus_scenery_0117.json is all black!
# Successfully processed campus_scenery_0117.json
# Warning: Mask for campus_scenery_0116.json is all black!
# Successfully processed campus_scenery_0116.json
# Warning: Mask for campus_scenery_0115.json is all black!
# Successfully processed campus_scenery_0115.json
# Warning: Mask for campus_scenery_0114.json is all black!
# Successfully processed campus_scenery_0114.json
# Warning: Mask for campus_scenery_0113.json is all black!
# Successfully processed campus_scenery_0113.json
# Warning: Mask for campus_scenery_0112.json is all black!
# Successfully processed campus_scenery_0112.json
# Warning: Mask for campus_scenery_0111.json is all black!
# Successfully processed campus_scenery_0111.json
# Warning: Mask for campus_scenery_0110.json is all black!
# Successfully processed campus_scenery_0110.json
# Warning: Mask for campus_scenery_0109.json is all black!
# Successfully processed campus_scenery_0109.json
# Warning: Mask for campus_scenery_0108.json is all black!
# Successfully processed campus_scenery_0108.json
# Warning: Mask for campus_scenery_0107.json is all black!
# Successfully processed campus_scenery_0107.json
# Warning: Mask for campus_scenery_0106.json is all black!
# Successfully processed campus_scenery_0106.json
# Warning: Mask for campus_scenery_0105.json is all black!
# Successfully processed campus_scenery_0105.json
# Warning: Mask for campus_scenery_0104.json is all black!
# Successfully processed campus_scenery_0104.json
# Warning: Mask for campus_scenery_0103.json is all black!
# Successfully processed campus_scenery_0103.json
# Warning: Mask for campus_scenery_0102.json is all black!
# Successfully processed campus_scenery_0102.json
# Warning: Mask for campus_scenery_0101.json is all black!
# Successfully processed campus_scenery_0101.json
# Warning: Mask for campus_scenery_0100.json is all black!
# Successfully processed campus_scenery_0100.json
# Warning: Mask for campus_scenery_0099.json is all black!
# Successfully processed campus_scenery_0099.json
# Warning: Mask for campus_scenery_0098.json is all black!
# Successfully processed campus_scenery_0098.json
# Warning: Mask for campus_scenery_0096.json is all black!
# Successfully processed campus_scenery_0096.json
# Warning: Mask for campus_scenery_0097.json is all black!
# Successfully processed campus_scenery_0097.json
# Warning: Mask for campus_scenery_0127.json is all black!
# Successfully processed campus_scenery_0127.json
# Warning: Mask for campus_scenery_0140.json is all black!
# Successfully processed campus_scenery_0140.json
# Warning: Mask for campus_scenery_0139.json is all black!
# Successfully processed campus_scenery_0139.json
# Warning: Mask for campus_scenery_0138.json is all black!
# Successfully processed campus_scenery_0138.json
# Warning: Mask for campus_scenery_0137.json is all black!
# Successfully processed campus_scenery_0137.json
# Warning: Mask for campus_scenery_0136.json is all black!
# Successfully processed campus_scenery_0136.json
# Warning: Mask for campus_scenery_0135.json is all black!
# Successfully processed campus_scenery_0135.json
# Warning: Mask for campus_scenery_0134.json is all black!
# Successfully processed campus_scenery_0134.json
# Warning: Mask for campus_scenery_0133.json is all black!
# Successfully processed campus_scenery_0133.json
# Warning: Mask for campus_scenery_0132.json is all black!
# Successfully processed campus_scenery_0132.json
# Warning: Mask for campus_scenery_0130.json is all black!
# Successfully processed campus_scenery_0130.json
# Warning: Mask for campus_scenery_0131.json is all black!
# Successfully processed campus_scenery_0131.json
# Warning: Mask for campus_scenery_0129.json is all black!
# Successfully processed campus_scenery_0129.json
# Warning: Mask for campus_scenery_0128.json is all black!
# Successfully processed campus_scenery_0128.json
# Warning: Mask for campus_scenery_0125.json is all black!
# Successfully processed campus_scenery_0125.json
# Warning: Mask for campus_scenery_0126.json is all black!
# Successfully processed campus_scenery_0126.json
# Warning: Mask for campus_scenery_0123.json is all black!
# Successfully processed campus_scenery_0123.json
# Warning: Mask for campus_scenery_0124.json is all black!
# Successfully processed campus_scenery_0124.json
# Warning: Mask for campus_scenery_0121.json is all black!
# Successfully processed campus_scenery_0121.json
# Warning: Mask for campus_scenery_0122.json is all black!
# Successfully processed campus_scenery_0122.json
# Warning: Mask for campus_scenery_0120.json is all black!
# Successfully processed campus_scenery_0120.json
# Warning: Mask for campus_scenery_0194.json is all black!
# Successfully processed campus_scenery_0194.json
# Warning: Mask for campus_scenery_0193.json is all black!
# Successfully processed campus_scenery_0193.json
# Warning: Mask for campus_scenery_0192.json is all black!
# Successfully processed campus_scenery_0192.json
# Warning: Mask for campus_scenery_0191.json is all black!
# Successfully processed campus_scenery_0191.json
# Warning: Mask for campus_scenery_0190.json is all black!
# Successfully processed campus_scenery_0190.json
# Warning: Mask for campus_scenery_0189.json is all black!
# Successfully processed campus_scenery_0189.json
# Warning: Mask for campus_scenery_0188.json is all black!
# Successfully processed campus_scenery_0188.json
# Warning: Mask for campus_scenery_0187.json is all black!
# Successfully processed campus_scenery_0187.json
# Warning: Mask for campus_scenery_0186.json is all black!
# Successfully processed campus_scenery_0186.json
# Warning: Mask for campus_scenery_0172.json is all black!
# Successfully processed campus_scenery_0172.json
# Warning: Mask for campus_scenery_0171.json is all black!
# Successfully processed campus_scenery_0171.json
# Warning: Mask for campus_scenery_0170.json is all black!
# Successfully processed campus_scenery_0170.json
# Warning: Mask for campus_scenery_0183.json is all black!
# Successfully processed campus_scenery_0183.json
# Warning: Mask for campus_scenery_0177.json is all black!
# Successfully processed campus_scenery_0177.json
# Warning: Mask for campus_scenery_0180.json is all black!
# Successfully processed campus_scenery_0180.json
# Warning: Mask for campus_scenery_0175.json is all black!
# Successfully processed campus_scenery_0175.json
# Warning: Mask for campus_scenery_0182.json is all black!
# Successfully processed campus_scenery_0182.json
# Warning: Mask for campus_scenery_0173.json is all black!
# Successfully processed campus_scenery_0173.json
# Warning: Mask for campus_scenery_0181.json is all black!
# Successfully processed campus_scenery_0181.json
# Warning: Mask for campus_scenery_0169.json is all black!
# Successfully processed campus_scenery_0169.json
# Warning: Mask for campus_scenery_0179.json is all black!
# Successfully processed campus_scenery_0179.json
# Warning: Mask for campus_scenery_0178.json is all black!
# Successfully processed campus_scenery_0178.json
# Warning: Mask for campus_scenery_0168.json is all black!
# Successfully processed campus_scenery_0168.json
# Warning: Mask for campus_scenery_0174.json is all black!
# Successfully processed campus_scenery_0174.json
# Warning: Mask for campus_scenery_0176.json is all black!
# Successfully processed campus_scenery_0176.json
# Warning: Mask for campus_scenery_0185.json is all black!
# Successfully processed campus_scenery_0185.json
# Warning: Mask for campus_scenery_0184.json is all black!
# Successfully processed campus_scenery_0184.json
# Warning: Mask for campus_scenery_0161.json is all black!
# Successfully processed campus_scenery_0161.json
# Warning: Mask for campus_scenery_0167.json is all black!
# Successfully processed campus_scenery_0167.json
# Warning: Mask for campus_scenery_0150.json is all black!
# Successfully processed campus_scenery_0150.json
# Warning: Mask for campus_scenery_0154.json is all black!
# Successfully processed campus_scenery_0154.json
# Warning: Mask for campus_scenery_0160.json is all black!
# Successfully processed campus_scenery_0160.json
# Warning: Mask for campus_scenery_0164.json is all black!
# Successfully processed campus_scenery_0164.json
# Warning: Mask for campus_scenery_0166.json is all black!
# Successfully processed campus_scenery_0166.json
# Warning: Mask for campus_scenery_0153.json is all black!
# Successfully processed campus_scenery_0153.json
# Warning: Mask for campus_scenery_0142.json is all black!
# Successfully processed campus_scenery_0142.json
# Warning: Mask for campus_scenery_0143.json is all black!
# Successfully processed campus_scenery_0143.json
# Warning: Mask for campus_scenery_0163.json is all black!
# Successfully processed campus_scenery_0163.json
# Warning: Mask for campus_scenery_0141.json is all black!
# Successfully processed campus_scenery_0141.json
# Warning: Mask for campus_scenery_0149.json is all black!
# Successfully processed campus_scenery_0149.json
# Warning: Mask for campus_scenery_0148.json is all black!
# Successfully processed campus_scenery_0148.json
# Warning: Mask for campus_scenery_0165.json is all black!
# Successfully processed campus_scenery_0165.json
# Warning: Mask for campus_scenery_0151.json is all black!
# Successfully processed campus_scenery_0151.json
# Warning: Mask for campus_scenery_0162.json is all black!
# Successfully processed campus_scenery_0162.json
# Warning: Mask for campus_scenery_0144.json is all black!
# Successfully processed campus_scenery_0144.json
# Warning: Mask for campus_scenery_0147.json is all black!
# Successfully processed campus_scenery_0147.json
# Warning: Mask for campus_scenery_0145.json is all black!
# Successfully processed campus_scenery_0145.json
# Warning: Mask for campus_scenery_0146.json is all black!
# Successfully processed campus_scenery_0146.json
# Warning: Mask for campus_scenery_0155.json is all black!
# Successfully processed campus_scenery_0155.json
# Warning: Mask for campus_scenery_0156.json is all black!
# Successfully processed campus_scenery_0156.json
# Warning: Mask for campus_scenery_0159.json is all black!
# Successfully processed campus_scenery_0159.json
# Warning: Mask for campus_scenery_0157.json is all black!
# Successfully processed campus_scenery_0157.json
# Warning: Mask for campus_scenery_0158.json is all black!
# Successfully processed campus_scenery_0158.json
# Warning: Mask for campus_scenery_0152.json is all black!
# Successfully processed campus_scenery_0152.json
# Warning: Mask for campus_scenery_0195.json is all black!
# Successfully processed campus_scenery_0195.json
# Warning: Mask for campus_scenery_0196.json is all black!
# Successfully processed campus_scenery_0196.json
# Warning: Mask for campus_scenery_0199.json is all black!
# Successfully processed campus_scenery_0199.json
# Warning: Mask for campus_scenery_0197.json is all black!
# Successfully processed campus_scenery_0197.json
# Warning: Mask for campus_scenery_0198.json is all black!
# Successfully processed campus_scenery_0198.json
# Conversion complete!
# Mask campus_scenery_0021_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0020_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0010_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0019_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0018_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0017_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0016_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0005_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0004_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0003_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0000_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0015_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0014_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0001_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0013_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0012_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0011_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0006_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0007_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0008_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0009_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0002_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0039_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0038_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0037_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0036_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0035_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0033_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0034_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0032_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0023_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0027_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0031_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0030_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0022_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0025_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0024_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0026_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0028_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0029_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0059_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0058_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0057_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0056_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0055_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0052_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0054_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0053_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0050_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0051_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0048_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0049_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0047_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0040_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0042_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0045_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0041_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0043_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0044_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0046_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0078_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0077_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0076_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0075_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0074_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0073_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0071_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0072_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0070_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0068_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0069_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0067_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0066_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0065_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0064_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0060_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0063_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0062_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0061_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0095_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0094_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0093_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0091_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0092_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0090_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0089_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0088_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0087_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0086_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0085_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0084_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0082_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0083_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0081_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0080_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0079_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0119_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0118_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0117_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0116_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0115_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0114_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0113_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0112_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0111_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0110_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0109_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0108_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0107_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0106_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0105_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0104_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0103_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0102_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0101_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0100_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0099_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0098_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0096_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0097_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0127_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0140_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0139_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0138_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0137_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0136_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0135_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0134_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0133_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0132_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0130_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0131_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0129_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0128_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0125_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0126_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0123_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0124_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0121_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0122_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0120_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0194_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0193_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0192_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0191_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0190_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0189_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0188_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0187_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0186_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0172_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0171_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0170_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0183_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0177_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0180_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0175_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0182_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0173_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0181_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0169_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0179_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0178_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0168_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0174_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0176_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0185_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0184_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0161_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0167_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0150_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0154_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0160_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0164_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0166_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0153_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0142_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0143_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0163_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0141_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0149_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0148_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0165_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0151_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0162_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0144_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0147_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0145_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0146_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0155_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0156_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0159_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0157_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0158_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0152_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0195_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0196_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0199_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0197_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!
# Mask campus_scenery_0198_colored_mask.png:
#   - Contains swimming pool: False
#   - Contains tennis court: False
#   WARNING: Mask contains neither class!

# %%
import os
import json
import numpy as np
from PIL import Image, ImageDraw

def print_json_info(json_path):
    """Print the labels used in the JSON file"""
    with open(json_path, 'r') as f:
        data = json.load(f)
    print(f"\nDebug info for {os.path.basename(json_path)}:")
    for shape in data['shapes']:
        print(f"Found label: '{shape['label']}'")

def labelme_json_to_colored_mask(json_path, output_path):
    """Convert LabelMe JSON file to colored mask"""
    # Read JSON file
    with open(json_path, 'r') as f:
        data = json.load(f)

    # Get image dimensions
    height = data['imageHeight']
    width = data['imageWidth']

    # Create empty RGB mask (black background)
    mask = np.zeros((height, width, 3), dtype=np.uint8)

    # Print the first shape's label to debug
    if data['shapes']:
        print(f"First shape label in {os.path.basename(json_path)}: {data['shapes'][0]['label']}")

    # Process each shape in the JSON
    for shape in data['shapes']:
        label = shape['label'].lower().strip()  # Convert to lowercase and remove extra spaces

        # Determine color based on label
        color = None
        if any(pool_term in label for pool_term in ['pool', 'swimming', 'swimming pool', 'swimmingpool']):
            color = (0, 0, 255)  # Blue for swimming pool
        elif any(court_term in label for court_term in ['court', 'tennis', 'tennis court', 'tenniscourt']):
            color = (0, 255, 0)  # Green for tennis court

        if color:
            # Get points
            points = shape['points']

            # Convert points to integer coordinates
            points = [(int(x), int(y)) for x, y in points]

            # Create temporary mask for this shape
            temp_mask = Image.new('RGB', (width, height), (0, 0, 0))
            draw = ImageDraw.Draw(temp_mask)

            # Draw the polygon with appropriate color
            draw.polygon(points, fill=color)

            # Convert to numpy array and combine with main mask
            shape_mask = np.array(temp_mask)
            mask = np.maximum(mask, shape_mask)

    # Save the colored mask
    Image.fromarray(mask).save(output_path)
    return mask

# Set your directories here
json_dir = "/content/drive/MyDrive/json-images"  # Change this to your JSON directory
output_dir = ""     # Change this to where you want to save masks

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# First, let's check what labels are actually in your JSON files
print("Checking JSON labels...")
for filename in os.listdir(json_dir):
    if filename.endswith('.json'):
        print_json_info(os.path.join(json_dir, filename))

print("\nNow converting files...")
# Process all JSON files
for filename in os.listdir(json_dir):
    if filename.endswith('.json'):
        json_path = os.path.join(json_dir, filename)
        mask_filename = filename.replace('.json', '_colored_mask.png')
        mask_path = os.path.join(output_dir, mask_filename)

        try:
            mask = labelme_json_to_colored_mask(json_path, mask_path)
            print(f"Processed {filename}")
        except Exception as e:
            print(f"Error processing {filename}: {str(e)}")

print("Conversion complete!")
# Out:
# Checking JSON labels...
#
# Debug info for campus_scenery_0021.json:
# Found label: 'campus_21'
#
# Debug info for campus_scenery_0020.json:
# Found label: 'campus_20'
#
# Debug info for campus_scenery_0010.json:
# Found label: 'campus_10'
#
# Debug info for campus_scenery_0019.json:
# Found label: 'campus_19'
#
# Debug info for campus_scenery_0018.json:
# Found label: 'campus_18'
#
# Debug info for campus_scenery_0017.json:
# Found label: 'campus_17'
#
# Debug info for campus_scenery_0016.json:
# Found label: 'campus_16'
#
# Debug info for campus_scenery_0005.json:
# Found label: 'campus_05'
#
# Debug info for campus_scenery_0004.json:
# Found label: 'campus_04'
#
# Debug info for campus_scenery_0003.json:
# Found label: 'campus_03'
#
# Debug info for campus_scenery_0000.json:
# Found label: 'campus_00'
#
# Debug info for campus_scenery_0015.json:
# Found label: 'campus_15'
#
# Debug info for campus_scenery_0014.json:
# Found label: 'campus_14'
#
# Debug info for campus_scenery_0001.json:
# Found label: 'campus_01'
#
# Debug info for campus_scenery_0013.json:
# Found label: 'campus_13'
#
# Debug info for campus_scenery_0012.json:
# Found label: 'campus_12'
#
# Debug info for campus_scenery_0011.json:
# Found label: 'campus_11'
#
# Debug info for campus_scenery_0006.json:
# Found label: 'campus_06'
#
# Debug info for campus_scenery_0007.json:
# Found label: 'campus_07'
#
# Debug info for campus_scenery_0008.json:
# Found label: 'campus_08'
#
# Debug info for campus_scenery_0009.json:
# Found label: 'campus_09'
#
# Debug info for campus_scenery_0002.json:
# Found label: 'campus_02'
#
# Debug info for campus_scenery_0039.json:
# Found label: 'campus_39'
#
# Debug info for campus_scenery_0038.json:
# Found label: 'campus_38'
#
# Debug info for campus_scenery_0037.json:
# Found label: 'campus_37'
#
# Debug info for campus_scenery_0036.json:
# Found label: 'campus_36'
#
# Debug info for campus_scenery_0035.json:
# Found label: 'campus_35'
#
# Debug info for campus_scenery_0033.json:
# Found label: 'campus_33'
#
# Debug info for campus_scenery_0034.json:
# Found label: 'campus_34'
#
# Debug info for campus_scenery_0032.json:
# Found label: 'campus_32'
#
# Debug info for campus_scenery_0023.json:
# Found label: 'campus_23'
#
# Debug info for campus_scenery_0027.json:
# Found label: 'campus_27'
#
# Debug info for campus_scenery_0031.json:
# Found label: 'campus_31'
#
# Debug info for campus_scenery_0030.json:
# Found label: 'campus_30'
#
# Debug info for campus_scenery_0022.json:
# Found label: 'campus_22'
#
# Debug info for campus_scenery_0025.json:
# Found label: 'campus_25'
#
# Debug info for campus_scenery_0024.json:
# Found label: 'campus_24'
#
# Debug info for campus_scenery_0026.json:
# Found label: 'campus_26'
#
# Debug info for campus_scenery_0028.json:
# Found label: 'campus_28'
#
# Debug info for campus_scenery_0029.json:
# Found label: 'campus_29'
#
# Debug info for campus_scenery_0059.json:
# Found label: 'campus_59'
#
# Debug info for campus_scenery_0058.json:
# Found label: 'campus_58'
#
# Debug info for campus_scenery_0057.json:
# Found label: 'campus_57'
#
# Debug info for campus_scenery_0056.json:
# Found label: 'campus_56'
#
# Debug info for campus_scenery_0055.json:
# Found label: 'campus_55'
#
# Debug info for campus_scenery_0052.json:
# Found label: 'campus_52'
#
# Debug info for campus_scenery_0054.json:
# Found label: 'campus_54'
#
# Debug info for campus_scenery_0053.json:
# Found label: 'campus_53'
#
# Debug info for campus_scenery_0050.json:
# Found label: 'campus_50'
#
# Debug info for campus_scenery_0051.json:
# Found label: 'campus_51'
#
# Debug info for campus_scenery_0048.json:
# Found label: 'campus_48'
#
# Debug info for campus_scenery_0049.json:
# Found label: 'campus_49'
#
# Debug info for campus_scenery_0047.json:
# Found label: 'campus_47'
#
# Debug info for campus_scenery_0040.json:
# Found label: 'campus_40'
#
# Debug info for campus_scenery_0042.json:
# Found label: 'campus_42'
#
# Debug info for campus_scenery_0045.json:
# Found label: 'campus_45'
#
# Debug info for campus_scenery_0041.json:
# Found label: 'campus_41'
#
# Debug info for campus_scenery_0043.json:
# Found label: 'campus_43'
#
# Debug info for campus_scenery_0044.json:
# Found label: 'campus_44'
#
# Debug info for campus_scenery_0046.json:
# Found label: 'campus_46'
#
# Debug info for campus_scenery_0078.json:
# Found label: 'campus_78'
#
# Debug info for campus_scenery_0077.json:
# Found label: 'campus_77'
#
# Debug info for campus_scenery_0076.json:
# Found label: 'campus_76'
#
# Debug info for campus_scenery_0075.json:
# Found label: 'campus_75'
#
# Debug info for campus_scenery_0074.json:
# Found label: 'campus_74'
#
# Debug info for campus_scenery_0073.json:
# Found label: 'campus_73'
#
# Debug info for campus_scenery_0071.json:
# Found label: 'campus_71'
#
# Debug info for campus_scenery_0072.json:
# Found label: 'campus_72'
#
# Debug info for campus_scenery_0070.json:
# Found label: 'campus_70'
#
# Debug info for campus_scenery_0068.json:
# Found label: 'campus_68'
#
# Debug info for campus_scenery_0069.json:
# Found label: 'campus_69'
#
# Debug info for campus_scenery_0067.json:
# Found label: 'campus_67'
#
# Debug info for campus_scenery_0066.json:
# Found label: 'campus_66'
#
# Debug info for campus_scenery_0065.json:
# Found label: 'campus_65'
#
# Debug info for campus_scenery_0064.json:
# Found label: 'campus_64'
#
# Debug info for campus_scenery_0060.json:
# Found label: 'campus_60'
#
# Debug info for campus_scenery_0063.json:
# Found label: 'campus_63'
#
# Debug info for campus_scenery_0062.json:
# Found label: 'campus_62'
#
# Debug info for campus_scenery_0061.json:
# Found label: 'campus_61'
#
# Debug info for campus_scenery_0095.json:
# Found label: 'campus_95'
#
# Debug info for campus_scenery_0094.json:
# Found label: 'campus_94'
#
# Debug info for campus_scenery_0093.json:
# Found label: 'campus_93'
#
# Debug info for campus_scenery_0091.json:
# Found label: 'campus_91'
#
# Debug info for campus_scenery_0092.json:
# Found label: 'campus_92'
#
# Debug info for campus_scenery_0090.json:
# Found label: 'campus_90'
#
# Debug info for campus_scenery_0089.json:
# Found label: 'campus_89'
#
# Debug info for campus_scenery_0088.json:
# Found label: 'campus_88'
#
# Debug info for campus_scenery_0087.json:
# Found label: 'campus_87'
#
# Debug info for campus_scenery_0086.json:
# Found label: 'campus_86'
#
# Debug info for campus_scenery_0085.json:
# Found label: 'campus_85'
#
# Debug info for campus_scenery_0084.json:
# Found label: 'campus_84'
#
# Debug info for campus_scenery_0082.json:
# Found label: 'campus_82'
#
# Debug info for campus_scenery_0083.json:
# Found label: 'campus_83'
#
# Debug info for campus_scenery_0081.json:
# Found label: 'campus_81'
#
# Debug info for campus_scenery_0080.json:
# Found label: 'campus_80'
#
# Debug info for campus_scenery_0079.json:
# Found label: 'campus_79'
#
# Debug info for campus_scenery_0119.json:
# Found label: 'campus_119'
#
# Debug info for campus_scenery_0118.json:
# Found label: 'campus_118'
#
# Debug info for campus_scenery_0117.json:
# Found label: 'campus_117'
#
# Debug info for campus_scenery_0116.json:
# Found label: 'campus_116'
#
# Debug info for campus_scenery_0115.json:
# Found label: 'campus_115'
#
# Debug info for campus_scenery_0114.json:
# Found label: 'campus_114'
#
# Debug info for campus_scenery_0113.json:
# Found label: 'campus_113'
#
# Debug info for campus_scenery_0112.json:
# Found label: 'campus_112'
#
# Debug info for campus_scenery_0111.json:
# Found label: 'campus_111'
#
# Debug info for campus_scenery_0110.json:
# Found label: 'campus_110'
#
# Debug info for campus_scenery_0109.json:
# Found label: 'campus_109'
#
# Debug info for campus_scenery_0108.json:
# Found label: 'campus_108'
#
# Debug info for campus_scenery_0107.json:
# Found label: 'campus_107'
#
# Debug info for campus_scenery_0106.json:
# Found label: 'campus_106'
#
# Debug info for campus_scenery_0105.json:
# Found label: 'campus_105'
#
# Debug info for campus_scenery_0104.json:
# Found label: 'campus_104'
#
# Debug info for campus_scenery_0103.json:
# Found label: 'campus_103'
#
# Debug info for campus_scenery_0102.json:
# Found label: 'campus_102'
#
# Debug info for campus_scenery_0101.json:
# Found label: 'campus_101'
#
# Debug info for campus_scenery_0100.json:
# Found label: 'campus_100'
#
# Debug info for campus_scenery_0099.json:
# Found label: 'campus_99'
#
# Debug info for campus_scenery_0098.json:
# Found label: 'campus_98'
#
# Debug info for campus_scenery_0096.json:
# Found label: 'campus_96'
#
# Debug info for campus_scenery_0097.json:
# Found label: 'campus_97'
#
# Debug info for campus_scenery_0127.json:
# Found label: 'campus_127'
#
# Debug info for campus_scenery_0140.json:
# Found label: 'campus_140'
#
# Debug info for campus_scenery_0139.json:
# Found label: 'campus_139'
#
# Debug info for campus_scenery_0138.json:
# Found label: 'campus_138'
#
# Debug info for campus_scenery_0137.json:
# Found label: 'campus_137'
#
# Debug info for campus_scenery_0136.json:
# Found label: 'campus_136'
#
# Debug info for campus_scenery_0135.json:
# Found label: 'campus_135'
#
# Debug info for campus_scenery_0134.json:
# Found label: 'campus_134'
#
# Debug info for campus_scenery_0133.json:
# Found label: 'campus_133'
#
# Debug info for campus_scenery_0132.json:
# Found label: 'campus_132'
#
# Debug info for campus_scenery_0130.json:
# Found label: 'campus_130'
#
# Debug info for campus_scenery_0131.json:
# Found label: 'campus_131'
#
# Debug info for campus_scenery_0129.json:
# Found label: 'campus_129'
#
# Debug info for campus_scenery_0128.json:
# Found label: 'campus_128'
#
# Debug info for campus_scenery_0125.json:
# Found label: 'campus_125'
#
# Debug info for campus_scenery_0126.json:
# Found label: 'campus_126'
#
# Debug info for campus_scenery_0123.json:
# Found label: 'campus_123'
#
# Debug info for campus_scenery_0124.json:
# Found label: 'campus_124'
#
# Debug info for campus_scenery_0121.json:
# Found label: 'campus_121'
#
# Debug info for campus_scenery_0122.json:
# Found label: 'campus_122'
#
# Debug info for campus_scenery_0120.json:
# Found label: 'campus_120'
#
# Debug info for campus_scenery_0194.json:
# Found label: 'campus_194'
#
# Debug info for campus_scenery_0193.json:
# Found label: 'campus_193'
#
# Debug info for campus_scenery_0192.json:
# Found label: 'campus_192'
#
# Debug info for campus_scenery_0191.json:
# Found label: 'campus_191'
#
# Debug info for campus_scenery_0190.json:
# Found label: 'campus_190'
#
# Debug info for campus_scenery_0189.json:
# Found label: 'campus_189'
#
# Debug info for campus_scenery_0188.json:
# Found label: 'campus_188'
#
# Debug info for campus_scenery_0187.json:
# Found label: 'campus_187'
#
# Debug info for campus_scenery_0186.json:
# Found label: 'campus_186'
#
# Debug info for campus_scenery_0172.json:
# Found label: 'campus_172'
#
# Debug info for campus_scenery_0171.json:
# Found label: 'campus_171'
#
# Debug info for campus_scenery_0170.json:
# Found label: 'campus_170'
#
# Debug info for campus_scenery_0183.json:
# Found label: 'campus_183'
#
# Debug info for campus_scenery_0177.json:
# Found label: 'campus_177'
#
# Debug info for campus_scenery_0180.json:
# Found label: 'campus_180'
#
# Debug info for campus_scenery_0175.json:
# Found label: 'campus_175'
#
# Debug info for campus_scenery_0182.json:
# Found label: 'campus_182'
#
# Debug info for campus_scenery_0173.json:
# Found label: 'campus_173'
#
# Debug info for campus_scenery_0181.json:
# Found label: 'campus_181'
#
# Debug info for campus_scenery_0169.json:
# Found label: 'campus_169'
#
# Debug info for campus_scenery_0179.json:
# Found label: 'campus_179'
#
# Debug info for campus_scenery_0178.json:
# Found label: 'campus_178'
#
# Debug info for campus_scenery_0168.json:
# Found label: 'campus_168'
#
# Debug info for campus_scenery_0174.json:
# Found label: 'campus_174'
#
# Debug info for campus_scenery_0176.json:
# Found label: 'campus_176'
#
# Debug info for campus_scenery_0185.json:
# Found label: 'campus_185'
#
# Debug info for campus_scenery_0184.json:
# Found label: 'campus_184'
#
# Debug info for campus_scenery_0161.json:
# Found label: 'campus_161'
#
# Debug info for campus_scenery_0167.json:
# Found label: 'campus_167'
#
# Debug info for campus_scenery_0150.json:
# Found label: 'campus_150'
#
# Debug info for campus_scenery_0154.json:
# Found label: 'campus_154'
#
# Debug info for campus_scenery_0160.json:
# Found label: 'campus_160'
#
# Debug info for campus_scenery_0164.json:
# Found label: 'campus_164'
#
# Debug info for campus_scenery_0166.json:
# Found label: 'campus_166'
#
# Debug info for campus_scenery_0153.json:
# Found label: 'campus_153'
#
# Debug info for campus_scenery_0142.json:
# Found label: 'campus_142'
#
# Debug info for campus_scenery_0143.json:
# Found label: 'campus_143'
#
# Debug info for campus_scenery_0163.json:
# Found label: 'campus_163'
#
# Debug info for campus_scenery_0141.json:
# Found label: 'campus_141'
#
# Debug info for campus_scenery_0149.json:
# Found label: 'campus_149'
#
# Debug info for campus_scenery_0148.json:
# Found label: 'campus_148'
#
# Debug info for campus_scenery_0165.json:
# Found label: 'campus_165'
#
# Debug info for campus_scenery_0151.json:
# Found label: 'campus_151'
#
# Debug info for campus_scenery_0162.json:
# Found label: 'campus_162'
#
# Debug info for campus_scenery_0144.json:
# Found label: 'campus_144'
#
# Debug info for campus_scenery_0147.json:
# Found label: 'campus_147'
#
# Debug info for campus_scenery_0145.json:
# Found label: 'campus_145'
#
# Debug info for campus_scenery_0146.json:
# Found label: 'campus_146'
#
# Debug info for campus_scenery_0155.json:
# Found label: 'campus_155'
#
# Debug info for campus_scenery_0156.json:
# Found label: 'campus_156'
#
# Debug info for campus_scenery_0159.json:
# Found label: 'campus_159'
#
# Debug info for campus_scenery_0157.json:
# Found label: 'campus_157'
#
# Debug info for campus_scenery_0158.json:
# Found label: 'campus_158'
#
# Debug info for campus_scenery_0152.json:
# Found label: 'campus_152'
#
# Debug info for campus_scenery_0195.json:
# Found label: 'campus_195'
#
# Debug info for campus_scenery_0196.json:
# Found label: 'campus_196'
#
# Debug info for campus_scenery_0199.json:
# Found label: 'campus_199'
#
# Debug info for campus_scenery_0197.json:
# Found label: 'campus_197'
#
# Debug info for campus_scenery_0198.json:
# Found label: 'campus_198'
#
# Now converting files...
# First shape label in campus_scenery_0021.json: campus_21
# Processed campus_scenery_0021.json
# First shape label in campus_scenery_0020.json: campus_20
# Processed campus_scenery_0020.json
# First shape label in campus_scenery_0010.json: campus_10
# Processed campus_scenery_0010.json
# First shape label in campus_scenery_0019.json: campus_19
# Processed campus_scenery_0019.json
# First shape label in campus_scenery_0018.json: campus_18
# Processed campus_scenery_0018.json
# First shape label in campus_scenery_0017.json: campus_17
# Processed campus_scenery_0017.json
# First shape label in campus_scenery_0016.json: campus_16
# Processed campus_scenery_0016.json
# First shape label in campus_scenery_0005.json: campus_05
# Processed campus_scenery_0005.json
# First shape label in campus_scenery_0004.json: campus_04
# Processed campus_scenery_0004.json
# First shape label in campus_scenery_0003.json: campus_03
# Processed campus_scenery_0003.json
# First shape label in campus_scenery_0000.json: campus_00
# Processed campus_scenery_0000.json
# First shape label in campus_scenery_0015.json: campus_15
# Processed campus_scenery_0015.json
# First shape label in campus_scenery_0014.json: campus_14
# Processed campus_scenery_0014.json
# First shape label in campus_scenery_0001.json: campus_01
# Processed campus_scenery_0001.json
# First shape label in campus_scenery_0013.json: campus_13
# Processed campus_scenery_0013.json
# First shape label in campus_scenery_0012.json: campus_12
# Processed campus_scenery_0012.json
# First shape label in campus_scenery_0011.json: campus_11
# Processed campus_scenery_0011.json
# First shape label in campus_scenery_0006.json: campus_06
# Processed campus_scenery_0006.json
# First shape label in campus_scenery_0007.json: campus_07
# Processed campus_scenery_0007.json
# First shape label in campus_scenery_0008.json: campus_08
# Processed campus_scenery_0008.json
# First shape label in campus_scenery_0009.json: campus_09
# Processed campus_scenery_0009.json
# First shape label in campus_scenery_0002.json: campus_02
# Processed campus_scenery_0002.json
# First shape label in campus_scenery_0039.json: campus_39
# Processed campus_scenery_0039.json
# First shape label in campus_scenery_0038.json: campus_38
# Processed campus_scenery_0038.json
# First shape label in campus_scenery_0037.json: campus_37
# Processed campus_scenery_0037.json
# First shape label in campus_scenery_0036.json: campus_36
# Processed campus_scenery_0036.json
# First shape label in campus_scenery_0035.json: campus_35
# Processed campus_scenery_0035.json
# First shape label in campus_scenery_0033.json: campus_33
# Processed campus_scenery_0033.json
# First shape label in campus_scenery_0034.json: campus_34
# Processed campus_scenery_0034.json
# First shape label in campus_scenery_0032.json: campus_32
# Processed campus_scenery_0032.json
# First shape label in campus_scenery_0023.json: campus_23
# Processed campus_scenery_0023.json
# First shape label in campus_scenery_0027.json: campus_27
# Processed campus_scenery_0027.json
# First shape label in campus_scenery_0031.json: campus_31
# Processed campus_scenery_0031.json
# First shape label in campus_scenery_0030.json: campus_30
# Processed campus_scenery_0030.json
# First shape label in campus_scenery_0022.json: campus_22
# Processed campus_scenery_0022.json
# First shape label in campus_scenery_0025.json: campus_25
# Processed campus_scenery_0025.json
# First shape label in campus_scenery_0024.json: campus_24
# Processed campus_scenery_0024.json
# First shape label in campus_scenery_0026.json: campus_26
# Processed campus_scenery_0026.json
# First shape label in campus_scenery_0028.json: campus_28
# Processed campus_scenery_0028.json
# First shape label in campus_scenery_0029.json: campus_29
# Processed campus_scenery_0029.json
# First shape label in campus_scenery_0059.json: campus_59
# Processed campus_scenery_0059.json
# First shape label in campus_scenery_0058.json: campus_58
# Processed campus_scenery_0058.json
# First shape label in campus_scenery_0057.json: campus_57
# Processed campus_scenery_0057.json
# First shape label in campus_scenery_0056.json: campus_56
# Processed campus_scenery_0056.json
# First shape label in campus_scenery_0055.json: campus_55
# Processed campus_scenery_0055.json
# First shape label in campus_scenery_0052.json: campus_52
# Processed campus_scenery_0052.json
# First shape label in campus_scenery_0054.json: campus_54
# Processed campus_scenery_0054.json
# First shape label in campus_scenery_0053.json: campus_53
# Processed campus_scenery_0053.json
# First shape label in campus_scenery_0050.json: campus_50
# Processed campus_scenery_0050.json
# First shape label in campus_scenery_0051.json: campus_51
# Processed campus_scenery_0051.json
# First shape label in campus_scenery_0048.json: campus_48
# Processed campus_scenery_0048.json
# First shape label in campus_scenery_0049.json: campus_49
# Processed campus_scenery_0049.json
# First shape label in campus_scenery_0047.json: campus_47
# Processed campus_scenery_0047.json
# First shape label in campus_scenery_0040.json: campus_40
# Processed campus_scenery_0040.json
# First shape label in campus_scenery_0042.json: campus_42
# Processed campus_scenery_0042.json
# First shape label in campus_scenery_0045.json: campus_45
# Processed campus_scenery_0045.json
# First shape label in campus_scenery_0041.json: campus_41
# Processed campus_scenery_0041.json
# First shape label in campus_scenery_0043.json: campus_43
# Processed campus_scenery_0043.json
# First shape label in campus_scenery_0044.json: campus_44
# Processed campus_scenery_0044.json
# First shape label in campus_scenery_0046.json: campus_46
# Processed campus_scenery_0046.json
# First shape label in campus_scenery_0078.json: campus_78
# Processed campus_scenery_0078.json
# First shape label in campus_scenery_0077.json: campus_77
# Processed campus_scenery_0077.json
# First shape label in campus_scenery_0076.json: campus_76
# Processed campus_scenery_0076.json
# First shape label in campus_scenery_0075.json: campus_75
# Processed campus_scenery_0075.json
# First shape label in campus_scenery_0074.json: campus_74
# Processed campus_scenery_0074.json
# First shape label in campus_scenery_0073.json: campus_73
# Processed campus_scenery_0073.json
# First shape label in campus_scenery_0071.json: campus_71
# Processed campus_scenery_0071.json
# First shape label in campus_scenery_0072.json: campus_72
# Processed campus_scenery_0072.json
# First shape label in campus_scenery_0070.json: campus_70
# Processed campus_scenery_0070.json
# First shape label in campus_scenery_0068.json: campus_68
# Processed campus_scenery_0068.json
# First shape label in campus_scenery_0069.json: campus_69
# Processed campus_scenery_0069.json
# First shape label in campus_scenery_0067.json: campus_67
# Processed campus_scenery_0067.json
# First shape label in campus_scenery_0066.json: campus_66
# Processed campus_scenery_0066.json
# First shape label in campus_scenery_0065.json: campus_65
# Processed campus_scenery_0065.json
# First shape label in campus_scenery_0064.json: campus_64
# Processed campus_scenery_0064.json
# First shape label in campus_scenery_0060.json: campus_60
# Processed campus_scenery_0060.json
# First shape label in campus_scenery_0063.json: campus_63
# Processed campus_scenery_0063.json
# First shape label in campus_scenery_0062.json: campus_62
# Processed campus_scenery_0062.json
# First shape label in campus_scenery_0061.json: campus_61
# Processed campus_scenery_0061.json
# First shape label in campus_scenery_0095.json: campus_95
# Processed campus_scenery_0095.json
# First shape label in campus_scenery_0094.json: campus_94
# Processed campus_scenery_0094.json
# First shape label in campus_scenery_0093.json: campus_93
# Processed campus_scenery_0093.json
# First shape label in campus_scenery_0091.json: campus_91
# Processed campus_scenery_0091.json
# First shape label in campus_scenery_0092.json: campus_92
# Processed campus_scenery_0092.json
# First shape label in campus_scenery_0090.json: campus_90
# Processed campus_scenery_0090.json
# First shape label in campus_scenery_0089.json: campus_89
# Processed campus_scenery_0089.json
# First shape label in campus_scenery_0088.json: campus_88
# Processed campus_scenery_0088.json
# First shape label in campus_scenery_0087.json: campus_87
# Processed campus_scenery_0087.json
# First shape label in campus_scenery_0086.json: campus_86
# Processed campus_scenery_0086.json
# First shape label in campus_scenery_0085.json: campus_85
# Processed campus_scenery_0085.json
# First shape label in campus_scenery_0084.json: campus_84
# Processed campus_scenery_0084.json
# First shape label in campus_scenery_0082.json: campus_82
# Processed campus_scenery_0082.json
# First shape label in campus_scenery_0083.json: campus_83
# Processed campus_scenery_0083.json
# First shape label in campus_scenery_0081.json: campus_81
# Processed campus_scenery_0081.json
# First shape label in campus_scenery_0080.json: campus_80
# Processed campus_scenery_0080.json
# First shape label in campus_scenery_0079.json: campus_79
# Processed campus_scenery_0079.json
# First shape label in campus_scenery_0119.json: campus_119
# Processed campus_scenery_0119.json
# First shape label in campus_scenery_0118.json: campus_118
# Processed campus_scenery_0118.json
# First shape label in campus_scenery_0117.json: campus_117
# Processed campus_scenery_0117.json
# First shape label in campus_scenery_0116.json: campus_116
# Processed campus_scenery_0116.json
# First shape label in campus_scenery_0115.json: campus_115
# Processed campus_scenery_0115.json
# First shape label in campus_scenery_0114.json: campus_114
# Processed campus_scenery_0114.json
# First shape label in campus_scenery_0113.json: campus_113
# Processed campus_scenery_0113.json
# First shape label in campus_scenery_0112.json: campus_112
# Processed campus_scenery_0112.json
# First shape label in campus_scenery_0111.json: campus_111
# Processed campus_scenery_0111.json
# First shape label in campus_scenery_0110.json: campus_110
# Processed campus_scenery_0110.json
# First shape label in campus_scenery_0109.json: campus_109
# Processed campus_scenery_0109.json
# First shape label in campus_scenery_0108.json: campus_108
# Processed campus_scenery_0108.json
# First shape label in campus_scenery_0107.json: campus_107
# Processed campus_scenery_0107.json
# First shape label in campus_scenery_0106.json: campus_106
# Processed campus_scenery_0106.json
# First shape label in campus_scenery_0105.json: campus_105
# Processed campus_scenery_0105.json
# First shape label in campus_scenery_0104.json: campus_104
# Processed campus_scenery_0104.json
# First shape label in campus_scenery_0103.json: campus_103
# Processed campus_scenery_0103.json
# First shape label in campus_scenery_0102.json: campus_102
# Processed campus_scenery_0102.json
# First shape label in campus_scenery_0101.json: campus_101
# Processed campus_scenery_0101.json
# First shape label in campus_scenery_0100.json: campus_100
# Processed campus_scenery_0100.json
# First shape label in campus_scenery_0099.json: campus_99
# Processed campus_scenery_0099.json
# First shape label in campus_scenery_0098.json: campus_98
# Processed campus_scenery_0098.json
# First shape label in campus_scenery_0096.json: campus_96
# Processed campus_scenery_0096.json
# First shape label in campus_scenery_0097.json: campus_97
# Processed campus_scenery_0097.json
# First shape label in campus_scenery_0127.json: campus_127
# Processed campus_scenery_0127.json
# First shape label in campus_scenery_0140.json: campus_140
# Processed campus_scenery_0140.json
# First shape label in campus_scenery_0139.json: campus_139
# Processed campus_scenery_0139.json
# First shape label in campus_scenery_0138.json: campus_138
# Processed campus_scenery_0138.json
# First shape label in campus_scenery_0137.json: campus_137
# Processed campus_scenery_0137.json
# First shape label in campus_scenery_0136.json: campus_136
# Processed campus_scenery_0136.json
# First shape label in campus_scenery_0135.json: campus_135
# Processed campus_scenery_0135.json
# First shape label in campus_scenery_0134.json: campus_134
# Processed campus_scenery_0134.json
# First shape label in campus_scenery_0133.json: campus_133
# Processed campus_scenery_0133.json
# First shape label in campus_scenery_0132.json: campus_132
# Processed campus_scenery_0132.json
# First shape label in campus_scenery_0130.json: campus_130
# Processed campus_scenery_0130.json
# First shape label in campus_scenery_0131.json: campus_131
# Processed campus_scenery_0131.json
# First shape label in campus_scenery_0129.json: campus_129
# Processed campus_scenery_0129.json
# First shape label in campus_scenery_0128.json: campus_128
# Processed campus_scenery_0128.json
# First shape label in campus_scenery_0125.json: campus_125
# Processed campus_scenery_0125.json
# First shape label in campus_scenery_0126.json: campus_126
# Processed campus_scenery_0126.json
# First shape label in campus_scenery_0123.json: campus_123
# Processed campus_scenery_0123.json
# First shape label in campus_scenery_0124.json: campus_124
# Processed campus_scenery_0124.json
# First shape label in campus_scenery_0121.json: campus_121
# Processed campus_scenery_0121.json
# First shape label in campus_scenery_0122.json: campus_122
# Processed campus_scenery_0122.json
# First shape label in campus_scenery_0120.json: campus_120
# Processed campus_scenery_0120.json
# First shape label in campus_scenery_0194.json: campus_194
# Processed campus_scenery_0194.json
# First shape label in campus_scenery_0193.json: campus_193
# Processed campus_scenery_0193.json
# First shape label in campus_scenery_0192.json: campus_192
# Processed campus_scenery_0192.json
# First shape label in campus_scenery_0191.json: campus_191
# Processed campus_scenery_0191.json
# First shape label in campus_scenery_0190.json: campus_190
# Processed campus_scenery_0190.json
# First shape label in campus_scenery_0189.json: campus_189
# Processed campus_scenery_0189.json
# First shape label in campus_scenery_0188.json: campus_188
# Processed campus_scenery_0188.json
# First shape label in campus_scenery_0187.json: campus_187
# Processed campus_scenery_0187.json
# First shape label in campus_scenery_0186.json: campus_186
# Processed campus_scenery_0186.json
# First shape label in campus_scenery_0172.json: campus_172
# Processed campus_scenery_0172.json
# First shape label in campus_scenery_0171.json: campus_171
# Processed campus_scenery_0171.json
# First shape label in campus_scenery_0170.json: campus_170
# Processed campus_scenery_0170.json
# First shape label in campus_scenery_0183.json: campus_183
# Processed campus_scenery_0183.json
# First shape label in campus_scenery_0177.json: campus_177
# Processed campus_scenery_0177.json
# First shape label in campus_scenery_0180.json: campus_180
# Processed campus_scenery_0180.json
# First shape label in campus_scenery_0175.json: campus_175
# Processed campus_scenery_0175.json
# First shape label in campus_scenery_0182.json: campus_182
# Processed campus_scenery_0182.json
# First shape label in campus_scenery_0173.json: campus_173
# Processed campus_scenery_0173.json
# First shape label in campus_scenery_0181.json: campus_181
# Processed campus_scenery_0181.json
# First shape label in campus_scenery_0169.json: campus_169
# Processed campus_scenery_0169.json
# First shape label in campus_scenery_0179.json: campus_179
# Processed campus_scenery_0179.json
# First shape label in campus_scenery_0178.json: campus_178
# Processed campus_scenery_0178.json
# First shape label in campus_scenery_0168.json: campus_168
# Processed campus_scenery_0168.json
# First shape label in campus_scenery_0174.json: campus_174
# Processed campus_scenery_0174.json
# First shape label in campus_scenery_0176.json: campus_176
# Processed campus_scenery_0176.json
# First shape label in campus_scenery_0185.json: campus_185
# Processed campus_scenery_0185.json
# First shape label in campus_scenery_0184.json: campus_184
# Processed campus_scenery_0184.json
# First shape label in campus_scenery_0161.json: campus_161
# Processed campus_scenery_0161.json
# First shape label in campus_scenery_0167.json: campus_167
# Processed campus_scenery_0167.json
# First shape label in campus_scenery_0150.json: campus_150
# Processed campus_scenery_0150.json
# First shape label in campus_scenery_0154.json: campus_154
# Processed campus_scenery_0154.json
# First shape label in campus_scenery_0160.json: campus_160
# Processed campus_scenery_0160.json
# First shape label in campus_scenery_0164.json: campus_164
# Processed campus_scenery_0164.json
# First shape label in campus_scenery_0166.json: campus_166
# Processed campus_scenery_0166.json
# First shape label in campus_scenery_0153.json: campus_153
# Processed campus_scenery_0153.json
# First shape label in campus_scenery_0142.json: campus_142
# Processed campus_scenery_0142.json
# First shape label in campus_scenery_0143.json: campus_143
# Processed campus_scenery_0143.json
# First shape label in campus_scenery_0163.json: campus_163
# Processed campus_scenery_0163.json
# First shape label in campus_scenery_0141.json: campus_141
# Processed campus_scenery_0141.json
# First shape label in campus_scenery_0149.json: campus_149
# Processed campus_scenery_0149.json
# First shape label in campus_scenery_0148.json: campus_148
# Processed campus_scenery_0148.json
# First shape label in campus_scenery_0165.json: campus_165
# Processed campus_scenery_0165.json
# First shape label in campus_scenery_0151.json: campus_151
# Processed campus_scenery_0151.json
# First shape label in campus_scenery_0162.json: campus_162
# Processed campus_scenery_0162.json
# First shape label in campus_scenery_0144.json: campus_144
# Processed campus_scenery_0144.json
# First shape label in campus_scenery_0147.json: campus_147
# Processed campus_scenery_0147.json
# First shape label in campus_scenery_0145.json: campus_145
# Processed campus_scenery_0145.json
# First shape label in campus_scenery_0146.json: campus_146
# Processed campus_scenery_0146.json
# First shape label in campus_scenery_0155.json: campus_155
# Processed campus_scenery_0155.json
# First shape label in campus_scenery_0156.json: campus_156
# Processed campus_scenery_0156.json
# First shape label in campus_scenery_0159.json: campus_159
# Processed campus_scenery_0159.json
# First shape label in campus_scenery_0157.json: campus_157
# Processed campus_scenery_0157.json
# First shape label in campus_scenery_0158.json: campus_158
# Processed campus_scenery_0158.json
# First shape label in campus_scenery_0152.json: campus_152
# Processed campus_scenery_0152.json
# First shape label in campus_scenery_0195.json: campus_195
# Processed campus_scenery_0195.json
# First shape label in campus_scenery_0196.json: campus_196
# Processed campus_scenery_0196.json
# First shape label in campus_scenery_0199.json: campus_199
# Processed campus_scenery_0199.json
# First shape label in campus_scenery_0197.json: campus_197
# Processed campus_scenery_0197.json
# First shape label in campus_scenery_0198.json: campus_198
# Processed campus_scenery_0198.json
# Conversion complete!

# %%
import cv2
import numpy as np
import os
from PIL import Image

def create_multiclass_mask(original_image_path, mask_output_path):
    """
    Creates a single-channel mask where:
    0 = background (black)
    1 = swimming pools (blue)
    2 = tennis courts (green)
    """
    # Read image
    img = cv2.imread(original_image_path)
    if img is None:
        print(f"Error: Could not read image {original_image_path}")
        return None

    # Create empty mask of same size as input image
    mask = np.zeros(img.shape[:2], dtype=np.uint8)

    # Convert to HSV for better color segmentation
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

    # Define color ranges for swimming pools (blue) - adjusted for better detection
    lower_blue = np.array([90, 50, 50])
    upper_blue = np.array([130, 255, 255])
    pool_mask = cv2.inRange(hsv, lower_blue, upper_blue)

    # Define color ranges for tennis courts (green) - adjusted for better detection
    lower_green = np.array([35, 30, 30])
    upper_green = np.array([85, 255, 255])
    court_mask = cv2.inRange(hsv, lower_green, upper_green)

    # Apply morphological operations to clean up the masks
    kernel = np.ones((5,5), np.uint8)
    pool_mask = cv2.morphologyEx(pool_mask, cv2.MORPH_CLOSE, kernel)
    court_mask = cv2.morphologyEx(court_mask, cv2.MORPH_CLOSE, kernel)

    # Assign class values
    mask[pool_mask > 0] = 1    # Swimming pools
    mask[court_mask > 0] = 2   # Tennis courts

    # Save both the single-channel mask and a visualization
    cv2.imwrite(mask_output_path, mask)

    # Create and save visualization
    vis_path = mask_output_path.replace('_mask.png', '_mask_vis.png')
    vis_mask = visualize_mask(mask)
    cv2.imwrite(vis_path, vis_mask)

    return mask

def visualize_mask(mask):
    """
    Visualize the mask with different colors
    Blue for pools, Green for courts, Black for background
    """
    if len(mask.shape) == 3:
        mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)

    vis_mask = np.zeros((*mask.shape, 3), dtype=np.uint8)
    vis_mask[mask == 0] = [0, 0, 0]      # Background = Black
    vis_mask[mask == 1] = [255, 0, 0]    # Pools = Blue (BGR)
    vis_mask[mask == 2] = [0, 255, 0]    # Tennis courts = Green

    return vis_mask

def process_dataset(input_dir, output_dir):
    """
    Process entire dataset of images
    """
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Get list of all images
    image_files = [f for f in os.listdir(input_dir) if f.endswith(('.jpg', '.png', '.jpeg'))]
    total_images = len(image_files)

    print(f"Found {total_images} images to process")

    for idx, filename in enumerate(image_files, 1):
        input_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, os.path.splitext(filename)[0] + '_mask.png')

        print(f"Processing image {idx}/{total_images}: {filename}")

        try:
            mask = create_multiclass_mask(input_path, output_path)
            if mask is not None:
                # Count pixels of each class
                pools = np.sum(mask == 1)
                courts = np.sum(mask == 2)
                print(f"  Found {pools} pool pixels and {courts} court pixels")
            else:
                print(f"  Failed to process {filename}")
        except Exception as e:
            print(f"  Error processing {filename}: {str(e)}")

# Main execution
if __name__ == "__main__":
    # Set your directories
    input_dir = "/content/drive/MyDrive/json-images"  # Change this to your images directory
    output_dir = "/content/drive/MyDrive/MyProject/mask_outputs7"  # Change this to where you want to save masks

    # Process the dataset
    process_dataset(input_dir, output_dir)

    print("Processing complete!")
# Out:
# Found 0 images to process
# Processing complete!

# %%
import os
import json
import numpy as np
import cv2
from PIL import Image, ImageDraw

def create_mask_from_json(json_path, output_path):
    """Convert LabelMe JSON to mask with appropriate colors"""
    # Read JSON file
    with open(json_path, 'r') as f:
        data = json.load(f)

    # Get image dimensions
    height = data['imageHeight']
    width = data['imageWidth']

    # Create empty mask
    mask = np.zeros((height, width), dtype=np.uint8)

    # Process each shape in the JSON
    for shape in data['shapes']:
        # Get points
        points = shape['points']
        # Convert points to integer coordinates
        points = [(int(x), int(y)) for x, y in points]

        # Create a mask for this polygon
        temp_mask = Image.new('L', (width, height), 0)
        draw = ImageDraw.Draw(temp_mask)

        # Draw the polygon
        if len(points) > 2:  # Check if we have enough points for a polygon
            draw.polygon(points, fill=1)

            # Convert to numpy array
            poly_mask = np.array(temp_mask)

            # Define class based on filename or label pattern
            # Modify this logic based on your naming convention
            # For example, if swimming pools are in certain file numbers
            filename = os.path.basename(json_path)
            if "pool" in filename.lower() or "swimming" in filename.lower():
                mask[poly_mask > 0] = 1  # Swimming pool
            elif "court" in filename.lower() or "tennis" in filename.lower():
                mask[poly_mask > 0] = 2  # Tennis court
            else:
                # Default to swimming pool for now - modify as needed
                mask[poly_mask > 0] = 1

    # Save both binary mask and visualization
    cv2.imwrite(output_path, mask)

    # Create and save visualization
    vis_mask = visualize_mask(mask)
    vis_path = output_path.replace('_mask.png', '_mask_vis.png')
    cv2.imwrite(vis_path, vis_mask)

    return mask

def visualize_mask(mask):
    """Create a colored visualization of the mask"""
    if len(mask.shape) == 3:
        mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)

    vis_mask = np.zeros((*mask.shape, 3), dtype=np.uint8)
    vis_mask[mask == 0] = [0, 0, 0]      # Background = Black
    vis_mask[mask == 1] = [0, 0, 255]    # Pools = Blue
    vis_mask[mask == 2] = [0, 255, 0]    # Tennis courts = Green

    return vis_mask

def process_json_files(json_dir, output_dir):
    """Process all JSON files in directory"""
    os.makedirs(output_dir, exist_ok=True)

    # Get all JSON files
    json_files = [f for f in os.listdir(json_dir) if f.endswith('.json')]
    total_files = len(json_files)

    print(f"Found {total_files} JSON files to process")

    for idx, filename in enumerate(json_files, 1):
        json_path = os.path.join(json_dir, filename)
        output_path = os.path.join(output_dir, filename.replace('.json', '_mask.png'))

        print(f"Processing {idx}/{total_files}: {filename}")

        try:
            mask = create_mask_from_json(json_path, output_path)
            # Count pixels of each class
            pools = np.sum(mask == 1)
            courts = np.sum(mask == 2)
            print(f"  Created mask with {pools} pool pixels and {courts} court pixels")
        except Exception as e:
            print(f"  Error processing {filename}: {str(e)}")

if __name__ == "__main__":
    # Set your directories
    json_dir = "/content/drive/MyDrive/json-images"  # Change this to your JSON directory
    output_dir = "/content/drive/MyDrive/MyProject/mask_outputs8"     # Change this to where you want to save masks

    print("Starting JSON to mask conversion...")
    process_json_files(json_dir, output_dir)
    print("Processing complete!")
# Out:
# Starting JSON to mask conversion...
# Found 200 JSON files to process
# Processing 1/200: campus_scenery_0021.json
#   Created mask with 30615 pool pixels and 0 court pixels
# Processing 2/200: campus_scenery_0020.json
#   Created mask with 115602 pool pixels and 0 court pixels
# Processing 3/200: campus_scenery_0010.json
#   Created mask with 63351 pool pixels and 0 court pixels
# Processing 4/200: campus_scenery_0019.json
#   Created mask with 56353 pool pixels and 0 court pixels
# Processing 5/200: campus_scenery_0018.json
#   Created mask with 89678 pool pixels and 0 court pixels
# Processing 6/200: campus_scenery_0017.json
#   Created mask with 88421 pool pixels and 0 court pixels
# Processing 7/200: campus_scenery_0016.json
#   Created mask with 33671 pool pixels and 0 court pixels
# Processing 8/200: campus_scenery_0005.json
#   Created mask with 104284 pool pixels and 0 court pixels
# Processing 9/200: campus_scenery_0004.json
#   Created mask with 51991 pool pixels and 0 court pixels
# Processing 10/200: campus_scenery_0003.json
#   Created mask with 6210 pool pixels and 0 court pixels
# Processing 11/200: campus_scenery_0000.json
#   Created mask with 109106 pool pixels and 0 court pixels
# Processing 12/200: campus_scenery_0015.json
#   Created mask with 61336 pool pixels and 0 court pixels
# Processing 13/200: campus_scenery_0014.json
#   Created mask with 24632 pool pixels and 0 court pixels
# Processing 14/200: campus_scenery_0001.json
#   Created mask with 40854 pool pixels and 0 court pixels
# Processing 15/200: campus_scenery_0013.json
#   Created mask with 23159 pool pixels and 0 court pixels
# Processing 16/200: campus_scenery_0012.json
#   Created mask with 78513 pool pixels and 0 court pixels
# Processing 17/200: campus_scenery_0011.json
#   Created mask with 109120 pool pixels and 0 court pixels
# Processing 18/200: campus_scenery_0006.json
#   Created mask with 97031 pool pixels and 0 court pixels
# Processing 19/200: campus_scenery_0007.json
#   Created mask with 28919 pool pixels and 0 court pixels
# Processing 20/200: campus_scenery_0008.json
#   Created mask with 50921 pool pixels and 0 court pixels
# Processing 21/200: campus_scenery_0009.json
#   Created mask with 14648 pool pixels and 0 court pixels
# Processing 22/200: campus_scenery_0002.json
#   Created mask with 40646 pool pixels and 0 court pixels
# Processing 23/200: campus_scenery_0039.json
#   Created mask with 34334 pool pixels and 0 court pixels
# Processing 24/200: campus_scenery_0038.json
#   Created mask with 73225 pool pixels and 0 court pixels
# Processing 25/200: campus_scenery_0037.json
#   Created mask with 69653 pool pixels and 0 court pixels
# Processing 26/200: campus_scenery_0036.json
#   Created mask with 25074 pool pixels and 0 court pixels
# Processing 27/200: campus_scenery_0035.json
#   Created mask with 17478 pool pixels and 0 court pixels
# Processing 28/200: campus_scenery_0033.json
#   Created mask with 37728 pool pixels and 0 court pixels
# Processing 29/200: campus_scenery_0034.json
#   Created mask with 56760 pool pixels and 0 court pixels
# Processing 30/200: campus_scenery_0032.json
#   Created mask with 85281 pool pixels and 0 court pixels
# Processing 31/200: campus_scenery_0023.json
#   Created mask with 102761 pool pixels and 0 court pixels
# Processing 32/200: campus_scenery_0027.json
#   Created mask with 66088 pool pixels and 0 court pixels
# Processing 33/200: campus_scenery_0031.json
#   Created mask with 48715 pool pixels and 0 court pixels
# Processing 34/200: campus_scenery_0030.json
#   Created mask with 53621 pool pixels and 0 court pixels
# Processing 35/200: campus_scenery_0022.json
#   Created mask with 46415 pool pixels and 0 court pixels
# Processing 36/200: campus_scenery_0025.json
#   Created mask with 72192 pool pixels and 0 court pixels
# Processing 37/200: campus_scenery_0024.json
#   Created mask with 26715 pool pixels and 0 court pixels
# Processing 38/200: campus_scenery_0026.json
#   Created mask with 95272 pool pixels and 0 court pixels
# Processing 39/200: campus_scenery_0028.json
#   Created mask with 75083 pool pixels and 0 court pixels
# Processing 40/200: campus_scenery_0029.json
#   Created mask with 63150 pool pixels and 0 court pixels
# Processing 41/200: campus_scenery_0059.json
#   Created mask with 46807 pool pixels and 0 court pixels
# Processing 42/200: campus_scenery_0058.json
#   Created mask with 117666 pool pixels and 0 court pixels
# Processing 43/200: campus_scenery_0057.json
#   Created mask with 206198 pool pixels and 0 court pixels
# Processing 44/200: campus_scenery_0056.json
#   Created mask with 153189 pool pixels and 0 court pixels
# Processing 45/200: campus_scenery_0055.json
#   Created mask with 55316 pool pixels and 0 court pixels
# Processing 46/200: campus_scenery_0052.json
#   Created mask with 81600 pool pixels and 0 court pixels
# Processing 47/200: campus_scenery_0054.json
#   Created mask with 75382 pool pixels and 0 court pixels
# Processing 48/200: campus_scenery_0053.json
#   Created mask with 36912 pool pixels and 0 court pixels
# Processing 49/200: campus_scenery_0050.json
#   Created mask with 111902 pool pixels and 0 court pixels
# Processing 50/200: campus_scenery_0051.json
#   Created mask with 71566 pool pixels and 0 court pixels
# Processing 51/200: campus_scenery_0048.json
#   Created mask with 46304 pool pixels and 0 court pixels
# Processing 52/200: campus_scenery_0049.json
#   Created mask with 173904 pool pixels and 0 court pixels
# Processing 53/200: campus_scenery_0047.json
#   Created mask with 27975 pool pixels and 0 court pixels
# Processing 54/200: campus_scenery_0040.json
#   Created mask with 24480 pool pixels and 0 court pixels
# Processing 55/200: campus_scenery_0042.json
#   Created mask with 72741 pool pixels and 0 court pixels
# Processing 56/200: campus_scenery_0045.json
#   Created mask with 12853 pool pixels and 0 court pixels
# Processing 57/200: campus_scenery_0041.json
#   Created mask with 48090 pool pixels and 0 court pixels
# Processing 58/200: campus_scenery_0043.json
#   Created mask with 43818 pool pixels and 0 court pixels
# Processing 59/200: campus_scenery_0044.json
#   Created mask with 38998 pool pixels and 0 court pixels
# Processing 60/200: campus_scenery_0046.json
#   Created mask with 26023 pool pixels and 0 court pixels
# Processing 61/200: campus_scenery_0078.json
#   Created mask with 17565 pool pixels and 0 court pixels
# Processing 62/200: campus_scenery_0077.json
#   Created mask with 88234 pool pixels and 0 court pixels
# Processing 63/200: campus_scenery_0076.json
#   Created mask with 49447 pool pixels and 0 court pixels
# Processing 64/200: campus_scenery_0075.json
#   Created mask with 101828 pool pixels and 0 court pixels
# Processing 65/200: campus_scenery_0074.json
#   Created mask with 82209 pool pixels and 0 court pixels
# Processing 66/200: campus_scenery_0073.json
#   Created mask with 65635 pool pixels and 0 court pixels
# Processing 67/200: campus_scenery_0071.json
#   Created mask with 108248 pool pixels and 0 court pixels
# Processing 68/200: campus_scenery_0072.json
#   Created mask with 104194 pool pixels and 0 court pixels
# Processing 69/200: campus_scenery_0070.json
#   Created mask with 120254 pool pixels and 0 court pixels
# Processing 70/200: campus_scenery_0068.json
#   Created mask with 4581 pool pixels and 0 court pixels
# Processing 71/200: campus_scenery_0069.json
#   Created mask with 63360 pool pixels and 0 court pixels
# Processing 72/200: campus_scenery_0067.json
#   Created mask with 33556 pool pixels and 0 court pixels
# Processing 73/200: campus_scenery_0066.json
#   Created mask with 34581 pool pixels and 0 court pixels
# Processing 74/200: campus_scenery_0065.json
#   Created mask with 17604 pool pixels and 0 court pixels
# Processing 75/200: campus_scenery_0064.json
#   Created mask with 26009 pool pixels and 0 court pixels
# Processing 76/200: campus_scenery_0060.json
#   Created mask with 32039 pool pixels and 0 court pixels
# Processing 77/200: campus_scenery_0063.json
#   Created mask with 26457 pool pixels and 0 court pixels
# Processing 78/200: campus_scenery_0062.json
#   Created mask with 16993 pool pixels and 0 court pixels
# Processing 79/200: campus_scenery_0061.json
#   Created mask with 40012 pool pixels and 0 court pixels
# Processing 80/200: campus_scenery_0095.json
#   Created mask with 71706 pool pixels and 0 court pixels
# Processing 81/200: campus_scenery_0094.json
#   Created mask with 37924 pool pixels and 0 court pixels
# Processing 82/200: campus_scenery_0093.json
#   Created mask with 39339 pool pixels and 0 court pixels
# Processing 83/200: campus_scenery_0091.json
#   Created mask with 46759 pool pixels and 0 court pixels
# Processing 84/200: campus_scenery_0092.json
#   Created mask with 82177 pool pixels and 0 court pixels
# Processing 85/200: campus_scenery_0090.json
#   Created mask with 20304 pool pixels and 0 court pixels
# Processing 86/200: campus_scenery_0089.json
#   Created mask with 55248 pool pixels and 0 court pixels
# Processing 87/200: campus_scenery_0088.json
#   Created mask with 21081 pool pixels and 0 court pixels
# Processing 88/200: campus_scenery_0087.json
#   Created mask with 48280 pool pixels and 0 court pixels
# Processing 89/200: campus_scenery_0086.json
#   Created mask with 120927 pool pixels and 0 court pixels
# Processing 90/200: campus_scenery_0085.json
#   Created mask with 22510 pool pixels and 0 court pixels
# Processing 91/200: campus_scenery_0084.json
#   Created mask with 206402 pool pixels and 0 court pixels
# Processing 92/200: campus_scenery_0082.json
#   Created mask with 57454 pool pixels and 0 court pixels
# Processing 93/200: campus_scenery_0083.json
#   Created mask with 159310 pool pixels and 0 court pixels
# Processing 94/200: campus_scenery_0081.json
#   Created mask with 52304 pool pixels and 0 court pixels
# Processing 95/200: campus_scenery_0080.json
#   Created mask with 56091 pool pixels and 0 court pixels
# Processing 96/200: campus_scenery_0079.json
#   Created mask with 18600 pool pixels and 0 court pixels
# Processing 97/200: campus_scenery_0119.json
#   Created mask with 120677 pool pixels and 0 court pixels
# Processing 98/200: campus_scenery_0118.json
#   Created mask with 121029 pool pixels and 0 court pixels
# Processing 99/200: campus_scenery_0117.json
#   Created mask with 39441 pool pixels and 0 court pixels
# Processing 100/200: campus_scenery_0116.json
#   Created mask with 29179 pool pixels and 0 court pixels
# Processing 101/200: campus_scenery_0115.json
#   Created mask with 36965 pool pixels and 0 court pixels
# Processing 102/200: campus_scenery_0114.json
#   Created mask with 85713 pool pixels and 0 court pixels
# Processing 103/200: campus_scenery_0113.json
#   Created mask with 30422 pool pixels and 0 court pixels
# Processing 104/200: campus_scenery_0112.json
#   Created mask with 14214 pool pixels and 0 court pixels
# Processing 105/200: campus_scenery_0111.json
#   Created mask with 148773 pool pixels and 0 court pixels
# Processing 106/200: campus_scenery_0110.json
#   Created mask with 23176 pool pixels and 0 court pixels
# Processing 107/200: campus_scenery_0109.json
#   Created mask with 110274 pool pixels and 0 court pixels
# Processing 108/200: campus_scenery_0108.json
#   Created mask with 37426 pool pixels and 0 court pixels
# Processing 109/200: campus_scenery_0107.json
#   Created mask with 90236 pool pixels and 0 court pixels
# Processing 110/200: campus_scenery_0106.json
#   Created mask with 59065 pool pixels and 0 court pixels
# Processing 111/200: campus_scenery_0105.json
#   Created mask with 16679 pool pixels and 0 court pixels
# Processing 112/200: campus_scenery_0104.json
#   Created mask with 65027 pool pixels and 0 court pixels
# Processing 113/200: campus_scenery_0103.json
#   Created mask with 42096 pool pixels and 0 court pixels
# Processing 114/200: campus_scenery_0102.json
#   Created mask with 12984 pool pixels and 0 court pixels
# Processing 115/200: campus_scenery_0101.json
#   Created mask with 24508 pool pixels and 0 court pixels
# Processing 116/200: campus_scenery_0100.json
#   Created mask with 26071 pool pixels and 0 court pixels
# Processing 117/200: campus_scenery_0099.json
#   Created mask with 119165 pool pixels and 0 court pixels
# Processing 118/200: campus_scenery_0098.json
#   Created mask with 8935 pool pixels and 0 court pixels
# Processing 119/200: campus_scenery_0096.json
#   Created mask with 41826 pool pixels and 0 court pixels
# Processing 120/200: campus_scenery_0097.json
#   Created mask with 27795 pool pixels and 0 court pixels
# Processing 121/200: campus_scenery_0127.json
#   Created mask with 86505 pool pixels and 0 court pixels
# Processing 122/200: campus_scenery_0140.json
#   Created mask with 69377 pool pixels and 0 court pixels
# Processing 123/200: campus_scenery_0139.json
#   Created mask with 51111 pool pixels and 0 court pixels
# Processing 124/200: campus_scenery_0138.json
#   Created mask with 35514 pool pixels and 0 court pixels
# Processing 125/200: campus_scenery_0137.json
#   Created mask with 80522 pool pixels and 0 court pixels
# Processing 126/200: campus_scenery_0136.json
#   Created mask with 26783 pool pixels and 0 court pixels
# Processing 127/200: campus_scenery_0135.json
#   Created mask with 48076 pool pixels and 0 court pixels
# Processing 128/200: campus_scenery_0134.json
#   Created mask with 29531 pool pixels and 0 court pixels
# Processing 129/200: campus_scenery_0133.json
#   Created mask with 75543 pool pixels and 0 court pixels
# Processing 130/200: campus_scenery_0132.json
#   Created mask with 70745 pool pixels and 0 court pixels
# Processing 131/200: campus_scenery_0130.json
#   Created mask with 84819 pool pixels and 0 court pixels
# Processing 132/200: campus_scenery_0131.json
#   Created mask with 48662 pool pixels and 0 court pixels
# Processing 133/200: campus_scenery_0129.json
#   Created mask with 31834 pool pixels and 0 court pixels
# Processing 134/200: campus_scenery_0128.json
#   Created mask with 17453 pool pixels and 0 court pixels
# Processing 135/200: campus_scenery_0125.json
#   Created mask with 31609 pool pixels and 0 court pixels
# Processing 136/200: campus_scenery_0126.json
#   Created mask with 64783 pool pixels and 0 court pixels
# Processing 137/200: campus_scenery_0123.json
#   Created mask with 50355 pool pixels and 0 court pixels
# Processing 138/200: campus_scenery_0124.json
#   Created mask with 42456 pool pixels and 0 court pixels
# Processing 139/200: campus_scenery_0121.json
#   Created mask with 91313 pool pixels and 0 court pixels
# Processing 140/200: campus_scenery_0122.json
#   Created mask with 27103 pool pixels and 0 court pixels
# Processing 141/200: campus_scenery_0120.json
#   Created mask with 86547 pool pixels and 0 court pixels
# Processing 142/200: campus_scenery_0194.json
#   Created mask with 45848 pool pixels and 0 court pixels
# Processing 143/200: campus_scenery_0193.json
#   Created mask with 63162 pool pixels and 0 court pixels
# Processing 144/200: campus_scenery_0192.json
#   Created mask with 54957 pool pixels and 0 court pixels
# Processing 145/200: campus_scenery_0191.json
#   Created mask with 31043 pool pixels and 0 court pixels
# Processing 146/200: campus_scenery_0190.json
#   Created mask with 33146 pool pixels and 0 court pixels
# Processing 147/200: campus_scenery_0189.json
#   Created mask with 90881 pool pixels and 0 court pixels
# Processing 148/200: campus_scenery_0188.json
#   Created mask with 43091 pool pixels and 0 court pixels
# Processing 149/200: campus_scenery_0187.json
#   Created mask with 36167 pool pixels and 0 court pixels
# Processing 150/200: campus_scenery_0186.json
#   Created mask with 52291 pool pixels and 0 court pixels
# Processing 151/200: campus_scenery_0172.json
#   Created mask with 39448 pool pixels and 0 court pixels
# Processing 152/200: campus_scenery_0171.json
#   Created mask with 53502 pool pixels and 0 court pixels
# Processing 153/200: campus_scenery_0170.json
#   Created mask with 140909 pool pixels and 0 court pixels
# Processing 154/200: campus_scenery_0183.json
#   Created mask with 139347 pool pixels and 0 court pixels
# Processing 155/200: campus_scenery_0177.json
#   Created mask with 40737 pool pixels and 0 court pixels
# Processing 156/200: campus_scenery_0180.json
#   Created mask with 31225 pool pixels and 0 court pixels
# Processing 157/200: campus_scenery_0175.json
#   Created mask with 46684 pool pixels and 0 court pixels
# Processing 158/200: campus_scenery_0182.json
#   Created mask with 22272 pool pixels and 0 court pixels
# Processing 159/200: campus_scenery_0173.json
#   Created mask with 34150 pool pixels and 0 court pixels
# Processing 160/200: campus_scenery_0181.json
#   Created mask with 34220 pool pixels and 0 court pixels
# Processing 161/200: campus_scenery_0169.json
#   Created mask with 69127 pool pixels and 0 court pixels
# Processing 162/200: campus_scenery_0179.json
#   Created mask with 28240 pool pixels and 0 court pixels
# Processing 163/200: campus_scenery_0178.json
#   Created mask with 59903 pool pixels and 0 court pixels
# Processing 164/200: campus_scenery_0168.json
#   Created mask with 25084 pool pixels and 0 court pixels
# Processing 165/200: campus_scenery_0174.json
#   Created mask with 21713 pool pixels and 0 court pixels
# Processing 166/200: campus_scenery_0176.json
#   Created mask with 30950 pool pixels and 0 court pixels
# Processing 167/200: campus_scenery_0185.json
#   Created mask with 58321 pool pixels and 0 court pixels
# Processing 168/200: campus_scenery_0184.json
#   Created mask with 9221 pool pixels and 0 court pixels
# Processing 169/200: campus_scenery_0161.json
#   Created mask with 65323 pool pixels and 0 court pixels
# Processing 170/200: campus_scenery_0167.json
#   Created mask with 46400 pool pixels and 0 court pixels
# Processing 171/200: campus_scenery_0150.json
#   Created mask with 36658 pool pixels and 0 court pixels
# Processing 172/200: campus_scenery_0154.json
#   Created mask with 45981 pool pixels and 0 court pixels
# Processing 173/200: campus_scenery_0160.json
#   Created mask with 28062 pool pixels and 0 court pixels
# Processing 174/200: campus_scenery_0164.json
#   Created mask with 89347 pool pixels and 0 court pixels
# Processing 175/200: campus_scenery_0166.json
#   Created mask with 103367 pool pixels and 0 court pixels
# Processing 176/200: campus_scenery_0153.json
#   Created mask with 50563 pool pixels and 0 court pixels
# Processing 177/200: campus_scenery_0142.json
#   Created mask with 58061 pool pixels and 0 court pixels
# Processing 178/200: campus_scenery_0143.json
#   Created mask with 8303 pool pixels and 0 court pixels
# Processing 179/200: campus_scenery_0163.json
#   Created mask with 32813 pool pixels and 0 court pixels
# Processing 180/200: campus_scenery_0141.json
#   Created mask with 46951 pool pixels and 0 court pixels
# Processing 181/200: campus_scenery_0149.json
#   Created mask with 156236 pool pixels and 0 court pixels
# Processing 182/200: campus_scenery_0148.json
#   Created mask with 55503 pool pixels and 0 court pixels
# Processing 183/200: campus_scenery_0165.json
#   Created mask with 80310 pool pixels and 0 court pixels
# Processing 184/200: campus_scenery_0151.json
#   Created mask with 25749 pool pixels and 0 court pixels
# Processing 185/200: campus_scenery_0162.json
#   Created mask with 33585 pool pixels and 0 court pixels
# Processing 186/200: campus_scenery_0144.json
#   Created mask with 43255 pool pixels and 0 court pixels
# Processing 187/200: campus_scenery_0147.json
#   Created mask with 24429 pool pixels and 0 court pixels
# Processing 188/200: campus_scenery_0145.json
#   Created mask with 21221 pool pixels and 0 court pixels
# Processing 189/200: campus_scenery_0146.json
#   Created mask with 51210 pool pixels and 0 court pixels
# Processing 190/200: campus_scenery_0155.json
#   Created mask with 53952 pool pixels and 0 court pixels
# Processing 191/200: campus_scenery_0156.json
#   Created mask with 10506 pool pixels and 0 court pixels
# Processing 192/200: campus_scenery_0159.json
#   Created mask with 109191 pool pixels and 0 court pixels
# Processing 193/200: campus_scenery_0157.json
#   Created mask with 18842 pool pixels and 0 court pixels
# Processing 194/200: campus_scenery_0158.json
#   Created mask with 123637 pool pixels and 0 court pixels
# Processing 195/200: campus_scenery_0152.json
#   Created mask with 36345 pool pixels and 0 court pixels
# Processing 196/200: campus_scenery_0195.json
#   Created mask with 18896 pool pixels and 0 court pixels
# Processing 197/200: campus_scenery_0196.json
#   Created mask with 64391 pool pixels and 0 court pixels
# Processing 198/200: campus_scenery_0199.json
#   Created mask with 35268 pool pixels and 0 court pixels
# Processing 199/200: campus_scenery_0197.json
#   Created mask with 34432 pool pixels and 0 court pixels
# Processing 200/200: campus_scenery_0198.json
#   Created mask with 101719 pool pixels and 0 court pixels
# Processing complete!

# %%
import os
import json
import numpy as np
import cv2
from PIL import Image, ImageDraw

# Define class mapping
class_mapping = {}  # Will store filename -> class mappings

def create_class_mapping(json_files):
    """Create mapping of files to classes"""
    print("\nFirst, let's identify which images are pools and which are courts.")
    print("For each image, enter:")
    print("1 for Swimming Pool")
    print("2 for Tennis Court")

    for json_file in json_files:
        while True:
            print(f"\nImage: {json_file}")
            choice = input("Is this a pool (1) or court (2)? ")
            if choice in ['1', '2']:
                class_mapping[json_file] = int(choice)
                break
            print("Invalid choice. Please enter 1 or 2.")

    # Save mapping to file for future reference
    with open('class_mapping.txt', 'w') as f:
        for filename, class_num in class_mapping.items():
            class_name = 'swimming_pool' if class_num == 1 else 'tennis_court'
            f.write(f"{filename}: {class_name}\n")

    print("\nClass mapping saved to 'class_mapping.txt'")

def create_mask_from_json(json_path, output_path):
    """Convert LabelMe JSON to mask with appropriate color based on class"""
    # Read JSON file
    with open(json_path, 'r') as f:
        data = json.load(f)

    # Get image dimensions
    height = data['imageHeight']
    width = data['imageWidth']

    # Create empty RGB mask
    mask = np.zeros((height, width, 3), dtype=np.uint8)

    # Get filename and class
    filename = os.path.basename(json_path)
    class_num = class_mapping.get(filename)

    if class_num is None:
        print(f"Warning: No class mapping found for {filename}")
        return None

    # Process each shape in the JSON
    for shape in data['shapes']:
        points = shape['points']
        points = [(int(x), int(y)) for x, y in points]

        if len(points) > 2:
            # Create temporary mask for this polygon
            temp_mask = Image.new('L', (width, height), 0)
            draw = ImageDraw.Draw(temp_mask)
            draw.polygon(points, fill=255)
            poly_mask = np.array(temp_mask)

            # Color based on class
            if class_num == 1:
                mask[poly_mask > 0] = [255, 0, 0]  # Blue for pools (BGR)
            else:
                mask[poly_mask > 0] = [0, 255, 0]  # Green for courts (BGR)

    # Save both colored mask and binary mask
    cv2.imwrite(output_path, mask)

    # Save binary mask (for training) - 0 for background, 1 for pools, 2 for courts
    binary_mask = np.zeros((height, width), dtype=np.uint8)
    binary_mask[mask[:,:,0] == 255] = 1  # Pools
    binary_mask[mask[:,:,1] == 255] = 2  # Courts
    binary_path = output_path.replace('_mask.png', '_binary_mask.png')
    cv2.imwrite(binary_path, binary_mask)

    return mask

def process_json_files(json_dir, output_dir):
    """Process all JSON files in directory"""
    os.makedirs(output_dir, exist_ok=True)

    # Get all JSON files
    json_files = [f for f in os.listdir(json_dir) if f.endswith('.json')]
    total_files = len(json_files)

    print(f"Found {total_files} JSON files to process")

    # Create class mapping if it doesn't exist
    if not class_mapping:
        create_class_mapping(json_files)

    # Process each file
    for idx, filename in enumerate(json_files, 1):
        json_path = os.path.join(json_dir, filename)
        output_path = os.path.join(output_dir, filename.replace('.json', '_mask.png'))

        print(f"\nProcessing {idx}/{total_files}: {filename}")
        class_name = 'swimming pool' if class_mapping[filename] == 1 else 'tennis court'
        print(f"Class: {class_name}")

        try:
            mask = create_mask_from_json(json_path, output_path)
            if mask is not None:
                print(f"Saved masks to {output_path}")

                # Display the mask
                cv2.imshow('Mask', mask)
                cv2.waitKey(500)

        except Exception as e:
            print(f"Error processing {filename}: {str(e)}")

    cv2.destroyAllWindows()

if __name__ == "__main__":
    # Set your directories
    json_dir = "/content/drive/MyDrive/json-images"
    output_dir = "/content/drive/MyDrive/MyProject/mask_outputs9"

    process_json_files(json_dir, output_dir)
    print("\nProcessing complete!")
    print("Created both colored visualization masks and binary masks for training")
# Out:
# Found 200 JSON files to process
#
# First, let's identify which images are pools and which are courts.
# For each image, enter:
# 1 for Swimming Pool
# 2 for Tennis Court
#
# Image: campus_scenery_0021.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0020.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0010.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0019.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0018.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0017.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0016.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0005.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0004.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0003.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0000.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0015.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0014.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0001.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0013.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0012.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0011.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0006.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0007.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0008.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0009.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0002.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0039.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0038.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0037.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0036.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0035.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0033.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0034.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0032.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0023.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0027.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0031.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0030.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0022.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0025.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0024.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0026.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0028.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0029.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0059.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0058.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0057.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0056.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0055.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0052.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0054.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0053.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0050.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0051.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0048.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0049.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0047.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0040.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0042.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0045.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0041.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0043.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0044.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0046.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0078.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0077.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0076.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0075.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0074.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0073.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0071.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0072.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0070.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0068.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0069.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0067.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0066.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0065.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0064.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0060.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0063.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0062.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0061.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0095.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0094.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0093.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0091.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0092.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0090.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0089.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0088.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0087.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0086.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0085.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0084.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0082.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0083.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0081.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0080.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0079.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0119.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0118.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0117.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0116.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0115.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0114.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0113.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0112.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0111.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0110.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0109.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0108.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0107.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0106.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0105.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0104.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0103.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0102.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0101.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0100.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0099.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0098.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0096.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0097.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0127.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0140.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0139.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0138.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0137.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0136.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0135.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0134.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0133.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0132.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0130.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0131.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0129.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0128.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0125.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0126.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0123.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0124.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0121.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0122.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0120.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0194.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0193.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0192.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0191.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0190.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0189.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0188.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0187.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0186.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0172.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0171.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0170.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0183.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0177.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0180.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0175.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0182.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0173.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0181.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0169.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0179.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0178.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0168.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0174.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0176.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0185.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0184.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0161.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0167.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0150.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0154.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0160.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0164.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0166.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0153.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0142.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0143.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0163.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0141.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0149.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0148.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0165.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0151.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0162.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0144.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0147.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0145.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0146.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0155.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0156.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0159.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0157.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0158.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0152.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0195.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0196.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0199.json
# Is this a pool (1) or court (2)? 1
#
# Image: campus_scenery_0197.json
# Is this a pool (1) or court (2)? 2
#
# Image: campus_scenery_0198.json
# Is this a pool (1) or court (2)? 2
#
# Class mapping saved to 'class_mapping.txt'
#
# Processing 1/200: campus_scenery_0021.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0021_mask.png
# Error processing campus_scenery_0021.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 2/200: campus_scenery_0020.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0020_mask.png
# Error processing campus_scenery_0020.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 3/200: campus_scenery_0010.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0010_mask.png
# Error processing campus_scenery_0010.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 4/200: campus_scenery_0019.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0019_mask.png
# Error processing campus_scenery_0019.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 5/200: campus_scenery_0018.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0018_mask.png
# Error processing campus_scenery_0018.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 6/200: campus_scenery_0017.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0017_mask.png
# Error processing campus_scenery_0017.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 7/200: campus_scenery_0016.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0016_mask.png
# Error processing campus_scenery_0016.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 8/200: campus_scenery_0005.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0005_mask.png
# Error processing campus_scenery_0005.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 9/200: campus_scenery_0004.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0004_mask.png
# Error processing campus_scenery_0004.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 10/200: campus_scenery_0003.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0003_mask.png
# Error processing campus_scenery_0003.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 11/200: campus_scenery_0000.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0000_mask.png
# Error processing campus_scenery_0000.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 12/200: campus_scenery_0015.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0015_mask.png
# Error processing campus_scenery_0015.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 13/200: campus_scenery_0014.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0014_mask.png
# Error processing campus_scenery_0014.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 14/200: campus_scenery_0001.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0001_mask.png
# Error processing campus_scenery_0001.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 15/200: campus_scenery_0013.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0013_mask.png
# Error processing campus_scenery_0013.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 16/200: campus_scenery_0012.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0012_mask.png
# Error processing campus_scenery_0012.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 17/200: campus_scenery_0011.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0011_mask.png
# Error processing campus_scenery_0011.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 18/200: campus_scenery_0006.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0006_mask.png
# Error processing campus_scenery_0006.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 19/200: campus_scenery_0007.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0007_mask.png
# Error processing campus_scenery_0007.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 20/200: campus_scenery_0008.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0008_mask.png
# Error processing campus_scenery_0008.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 21/200: campus_scenery_0009.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0009_mask.png
# Error processing campus_scenery_0009.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 22/200: campus_scenery_0002.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0002_mask.png
# Error processing campus_scenery_0002.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 23/200: campus_scenery_0039.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0039_mask.png
# Error processing campus_scenery_0039.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 24/200: campus_scenery_0038.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0038_mask.png
# Error processing campus_scenery_0038.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 25/200: campus_scenery_0037.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0037_mask.png
# Error processing campus_scenery_0037.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 26/200: campus_scenery_0036.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0036_mask.png
# Error processing campus_scenery_0036.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 27/200: campus_scenery_0035.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0035_mask.png
# Error processing campus_scenery_0035.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 28/200: campus_scenery_0033.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0033_mask.png
# Error processing campus_scenery_0033.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 29/200: campus_scenery_0034.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0034_mask.png
# Error processing campus_scenery_0034.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 30/200: campus_scenery_0032.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0032_mask.png
# Error processing campus_scenery_0032.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 31/200: campus_scenery_0023.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0023_mask.png
# Error processing campus_scenery_0023.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 32/200: campus_scenery_0027.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0027_mask.png
# Error processing campus_scenery_0027.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 33/200: campus_scenery_0031.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0031_mask.png
# Error processing campus_scenery_0031.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 34/200: campus_scenery_0030.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0030_mask.png
# Error processing campus_scenery_0030.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 35/200: campus_scenery_0022.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0022_mask.png
# Error processing campus_scenery_0022.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 36/200: campus_scenery_0025.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0025_mask.png
# Error processing campus_scenery_0025.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 37/200: campus_scenery_0024.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0024_mask.png
# Error processing campus_scenery_0024.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 38/200: campus_scenery_0026.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0026_mask.png
# Error processing campus_scenery_0026.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 39/200: campus_scenery_0028.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0028_mask.png
# Error processing campus_scenery_0028.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 40/200: campus_scenery_0029.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0029_mask.png
# Error processing campus_scenery_0029.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 41/200: campus_scenery_0059.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0059_mask.png
# Error processing campus_scenery_0059.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 42/200: campus_scenery_0058.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0058_mask.png
# Error processing campus_scenery_0058.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 43/200: campus_scenery_0057.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0057_mask.png
# Error processing campus_scenery_0057.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 44/200: campus_scenery_0056.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0056_mask.png
# Error processing campus_scenery_0056.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 45/200: campus_scenery_0055.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0055_mask.png
# Error processing campus_scenery_0055.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 46/200: campus_scenery_0052.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0052_mask.png
# Error processing campus_scenery_0052.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 47/200: campus_scenery_0054.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0054_mask.png
# Error processing campus_scenery_0054.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 48/200: campus_scenery_0053.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0053_mask.png
# Error processing campus_scenery_0053.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 49/200: campus_scenery_0050.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0050_mask.png
# Error processing campus_scenery_0050.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 50/200: campus_scenery_0051.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0051_mask.png
# Error processing campus_scenery_0051.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 51/200: campus_scenery_0048.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0048_mask.png
# Error processing campus_scenery_0048.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 52/200: campus_scenery_0049.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0049_mask.png
# Error processing campus_scenery_0049.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 53/200: campus_scenery_0047.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0047_mask.png
# Error processing campus_scenery_0047.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 54/200: campus_scenery_0040.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0040_mask.png
# Error processing campus_scenery_0040.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 55/200: campus_scenery_0042.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0042_mask.png
# Error processing campus_scenery_0042.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 56/200: campus_scenery_0045.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0045_mask.png
# Error processing campus_scenery_0045.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 57/200: campus_scenery_0041.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0041_mask.png
# Error processing campus_scenery_0041.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 58/200: campus_scenery_0043.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0043_mask.png
# Error processing campus_scenery_0043.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 59/200: campus_scenery_0044.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0044_mask.png
# Error processing campus_scenery_0044.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 60/200: campus_scenery_0046.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0046_mask.png
# Error processing campus_scenery_0046.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 61/200: campus_scenery_0078.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0078_mask.png
# Error processing campus_scenery_0078.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 62/200: campus_scenery_0077.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0077_mask.png
# Error processing campus_scenery_0077.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 63/200: campus_scenery_0076.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0076_mask.png
# Error processing campus_scenery_0076.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 64/200: campus_scenery_0075.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0075_mask.png
# Error processing campus_scenery_0075.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 65/200: campus_scenery_0074.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0074_mask.png
# Error processing campus_scenery_0074.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 66/200: campus_scenery_0073.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0073_mask.png
# Error processing campus_scenery_0073.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 67/200: campus_scenery_0071.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0071_mask.png
# Error processing campus_scenery_0071.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 68/200: campus_scenery_0072.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0072_mask.png
# Error processing campus_scenery_0072.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 69/200: campus_scenery_0070.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0070_mask.png
# Error processing campus_scenery_0070.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 70/200: campus_scenery_0068.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0068_mask.png
# Error processing campus_scenery_0068.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 71/200: campus_scenery_0069.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0069_mask.png
# Error processing campus_scenery_0069.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 72/200: campus_scenery_0067.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0067_mask.png
# Error processing campus_scenery_0067.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 73/200: campus_scenery_0066.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0066_mask.png
# Error processing campus_scenery_0066.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 74/200: campus_scenery_0065.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0065_mask.png
# Error processing campus_scenery_0065.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 75/200: campus_scenery_0064.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0064_mask.png
# Error processing campus_scenery_0064.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 76/200: campus_scenery_0060.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0060_mask.png
# Error processing campus_scenery_0060.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 77/200: campus_scenery_0063.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0063_mask.png
# Error processing campus_scenery_0063.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 78/200: campus_scenery_0062.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0062_mask.png
# Error processing campus_scenery_0062.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 79/200: campus_scenery_0061.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0061_mask.png
# Error processing campus_scenery_0061.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 80/200: campus_scenery_0095.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0095_mask.png
# Error processing campus_scenery_0095.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 81/200: campus_scenery_0094.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0094_mask.png
# Error processing campus_scenery_0094.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 82/200: campus_scenery_0093.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0093_mask.png
# Error processing campus_scenery_0093.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 83/200: campus_scenery_0091.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0091_mask.png
# Error processing campus_scenery_0091.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# ...
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 163/200: campus_scenery_0178.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0178_mask.png
# Error processing campus_scenery_0178.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 164/200: campus_scenery_0168.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0168_mask.png
# Error processing campus_scenery_0168.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 165/200: campus_scenery_0174.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0174_mask.png
# Error processing campus_scenery_0174.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 166/200: campus_scenery_0176.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0176_mask.png
# Error processing campus_scenery_0176.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 167/200: campus_scenery_0185.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0185_mask.png
# Error processing campus_scenery_0185.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 168/200: campus_scenery_0184.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0184_mask.png
# Error processing campus_scenery_0184.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 169/200: campus_scenery_0161.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0161_mask.png
# Error processing campus_scenery_0161.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 170/200: campus_scenery_0167.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0167_mask.png
# Error processing campus_scenery_0167.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 171/200: campus_scenery_0150.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0150_mask.png
# Error processing campus_scenery_0150.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 172/200: campus_scenery_0154.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0154_mask.png
# Error processing campus_scenery_0154.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 173/200: campus_scenery_0160.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0160_mask.png
# Error processing campus_scenery_0160.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 174/200: campus_scenery_0164.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0164_mask.png
# Error processing campus_scenery_0164.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 175/200: campus_scenery_0166.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0166_mask.png
# Error processing campus_scenery_0166.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 176/200: campus_scenery_0153.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0153_mask.png
# Error processing campus_scenery_0153.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 177/200: campus_scenery_0142.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0142_mask.png
# Error processing campus_scenery_0142.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 178/200: campus_scenery_0143.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0143_mask.png
# Error processing campus_scenery_0143.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 179/200: campus_scenery_0163.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0163_mask.png
# Error processing campus_scenery_0163.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 180/200: campus_scenery_0141.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0141_mask.png
# Error processing campus_scenery_0141.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 181/200: campus_scenery_0149.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0149_mask.png
# Error processing campus_scenery_0149.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 182/200: campus_scenery_0148.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0148_mask.png
# Error processing campus_scenery_0148.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 183/200: campus_scenery_0165.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0165_mask.png
# Error processing campus_scenery_0165.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 184/200: campus_scenery_0151.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0151_mask.png
# Error processing campus_scenery_0151.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 185/200: campus_scenery_0162.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0162_mask.png
# Error processing campus_scenery_0162.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 186/200: campus_scenery_0144.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0144_mask.png
# Error processing campus_scenery_0144.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 187/200: campus_scenery_0147.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0147_mask.png
# Error processing campus_scenery_0147.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 188/200: campus_scenery_0145.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0145_mask.png
# Error processing campus_scenery_0145.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 189/200: campus_scenery_0146.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0146_mask.png
# Error processing campus_scenery_0146.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 190/200: campus_scenery_0155.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0155_mask.png
# Error processing campus_scenery_0155.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 191/200: campus_scenery_0156.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0156_mask.png
# Error processing campus_scenery_0156.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 192/200: campus_scenery_0159.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0159_mask.png
# Error processing campus_scenery_0159.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 193/200: campus_scenery_0157.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0157_mask.png
# Error processing campus_scenery_0157.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 194/200: campus_scenery_0158.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0158_mask.png
# Error processing campus_scenery_0158.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 195/200: campus_scenery_0152.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0152_mask.png
# Error processing campus_scenery_0152.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 196/200: campus_scenery_0195.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0195_mask.png
# Error processing campus_scenery_0195.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 197/200: campus_scenery_0196.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0196_mask.png
# Error processing campus_scenery_0196.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 198/200: campus_scenery_0199.json
# Class: swimming pool
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0199_mask.png
# Error processing campus_scenery_0199.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 199/200: campus_scenery_0197.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0197_mask.png
# Error processing campus_scenery_0197.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing 200/200: campus_scenery_0198.json
# Class: tennis court
# Saved masks to /content/drive/MyDrive/MyProject/mask_outputs9/campus_scenery_0198_mask.png
# Error processing campus_scenery_0198.json: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
#
#
# Processing complete!
# Created both colored visualization masks and binary masks for training
